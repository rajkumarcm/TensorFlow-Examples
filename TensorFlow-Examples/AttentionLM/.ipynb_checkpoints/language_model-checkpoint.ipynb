# %%
"""-------------------------------------------------
Author: Rajkumar Conjeevaram Mohan
Email: rajkumarcm@yahoo.com
Program: Language Model with Attention mechanism
-------------------------------------------------"""
# Out:
# '-------------------------------------------------\nAuthor: Rajkumar Conjeevaram Mohan\nEmail: rajkumarcm@yahoo.com\nProgram: Language Model with Attention mechanism\n-------------------------------------------------'

# %%
import pdb
import pickle
import math
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH']='true'
import numpy as np
# %matplotlib notebook
import matplotlib
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow_datasets as tfds
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
# %config Completer.use_jedi = False

# %% [markdown]
# ### Load data

# %%
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)

# %%
train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

for s, _ in train_data:
    training_sentences.append(s.numpy().decode('utf8'))
for s, _ in test_data:
    testing_sentences.append(s.numpy().decode('utf8'))

N_TR = len(training_sentences)
N_TS = len(testing_sentences)
N_VL = int(0.2 * N_TR)
validation_sentences = training_sentences[-N_VL:]
training_sentences = training_sentences[:-N_VL]
N_TR = len(training_sentences)

# %%
print(f'Length of training set: {N_TR}')
print(f'Length of testing set: {N_TS}')
print(f'Length of validation set: {N_VL}')
# Out:
# Length of training set: 20000
# Length of testing set: 25000
# Length of validation set: 5000

# %% [markdown]
# #### Limit data to subset of 1000 examples

# %%
# Temporary
training_sentences = training_sentences[:1000]
validation_sentences = validation_sentences[:200]
N_TR = 1000
N_VL = 200

# %% [markdown]
# #### Tokenizer

# %%
VOCAB_SIZE = 10000
tokenizer = Tokenizer(num_words=VOCAB_SIZE, oov_token='<OOV>')
tokenizer.fit_on_texts(training_sentences)
index_word = tokenizer.index_word

# %%
tmp_length1 = []
tmp_length2 = []

for sentence in training_sentences:
    tmp_tokens = tokenizer.texts_to_sequences([sentence])[0]
    tmp_length1.append(len(tmp_tokens))

for sentence in testing_sentences:
    tmp_tokens = tokenizer.texts_to_sequences([sentence])[0]
    tmp_length2.append(len(tmp_tokens))

tmp_length1 = np.max(tmp_length1)
tmp_length2 = np.max(tmp_length2)
MAX_LEN = np.max([tmp_length1, tmp_length2])

# %% [markdown]
# #### Create mask

# %%
noise = 0.15
MASK = ['X']
from numpy.random import random
def get_masks(tokens_seq):
    masks = []
    for tokens in tokens_seq:
        previously_masked = False
        mask = []
        for token in tokens:
            if random() < noise:
                if not previously_masked:
                    mask.append(True)
                else:
                    mask.append(False)
            else:
                mask.append(False)
        masks.append(mask)
    return masks

# %% [markdown]
# ### Data preprocessing

# %%
def preprocess(review):
    tokenized_review = tokenizer.texts_to_sequences([str(review)])[0]
    masks = get_masks([tokenized_review])
    tokenized_review = pad_sequences([tokenized_review], maxlen=MAX_LEN)
    tokenized_review = tokenized_review.astype(np.int16)
    masks = pad_sequences(masks, maxlen=MAX_LEN)
    masks = masks.astype(np.bool)
    return np.squeeze(tokenized_review), np.squeeze(masks)

# %%
def stream(data):
    for i in range(len(data)):
        review = data[i]
        tokenized_review, mask = preprocess(review)
        yield tokenized_review, mask

# %%
def make_dict(tokenized_review, mask):
    return {'input_key':tokenized_review, 'input_query':tokenized_review}, \
           {'mask':mask, 'target':tokenized_review}

# %% [markdown]
# #### Verify whether the preprocessing steps work as they should

# %%
train_gen = stream(training_sentences)
for review, mask in train_gen:
    tmp_review = review
    tmp_mask = mask
    print('Stream output shape-----------------------')
    print(f'train_token.shape={review.shape}, dtype={review.dtype}')
    print(f'mask.shape={mask.shape}, dtype={mask.dtype}')
    print('------------------------------------------\n')
    break
# Out:
# Stream output shape-----------------------
# train_token.shape=(2332,), dtype=int16
# mask.shape=(2332,), dtype=bool
# ------------------------------------------

# %%
# input_x, target_x = make_dict(tmp_review, tmp_mask)
# print(f'input_x["input_key"].shape={input_x["input_key"].shape}')
# print(f'input_x["input_key"].shape={input_x["input_key"].shape}')
# print(f'mask.shape={target_x["mask"].shape}')

# %% [markdown]
# ### Now, let's create data pipeline

# %%
BATCH_SIZE = 1

train_gen = tf.data.Dataset.from_generator(generator=stream, 
                                           args=[training_sentences], 
                                           output_shapes=([MAX_LEN], [MAX_LEN]),
                                           output_types=(tf.int16, tf.bool)
                                          )
train_gen = train_gen.repeat().batch(BATCH_SIZE)#.map(make_dict).prefetch(3)

val_gen = tf.data.Dataset.from_generator(generator=stream,
                                         args=[validation_sentences],
                                         output_shapes=([MAX_LEN], [MAX_LEN]),
                                         output_types=(tf.int16, tf.bool))
val_gen = val_gen.repeat().batch(BATCH_SIZE)#.map(make_dict).prefetch(3)

tes_gen = tf.data.Dataset.from_generator(generator=stream,
                                         args=[testing_sentences],
                                         output_shapes=([MAX_LEN], [MAX_LEN]),
                                         output_types=(tf.int16, tf.bool))
tes_gen = val_gen.repeat().batch(BATCH_SIZE)#.map(make_dict).prefetch(3)

# %% [markdown]
# ### Now once again let's confirm whether data generator work as they should

# %% [markdown]
# ##### Use the following snippet when map function is enabled

# %%
# for review_dict, target_dict in train_gen.as_numpy_iterator():
#     print(f'review: {review_dict["input_key"].shape}')
#     print(f'mask: {target_dict["mask"].shape}')
#     break

# %% [markdown]
# ##### Use this when map is disabled

# %%
for tokenized_review, mask in train_gen:
    input_x, target_x = make_dict(tokenized_review, mask)
    print('Output signature of train generator-------------')
    print(f'review: {tokenized_review.shape}')
    print(f'mask: {mask.shape}')
    print('------------------------------------------------\n')
    break
# Out:
# Output signature of train generator-------------
# review: (1, 2332)
# mask: (1, 2332)
# ------------------------------------------------

# %%
def accuracy(y_true, y_pred):
    y_pred = tf.cast(tf.argmax(y_pred, axis=-1), tf.int16)
    y_pred = tf.squeeze(y_pred)  # batch_size x max_len
    target = tf.cast(y_true['target'], tf.int16)  # batch_size x max_len
    correct = tf.cast(tf.equal(y_pred, target), dtype=tf.int16)
    mask = tf.cast(y_true['mask'], tf.int16)
    acc = tf.reduce_sum(correct * mask)/tf.reduce_sum(mask)
    return acc

# %%
def loss(y_true, y_pred):
    mask = y_true['mask']
    target = tf.one_hot(depth=VOCAB_SIZE+1, indices=tf.cast(y_true['target'], tf.int32))
    loss = -1 * (target * tf.math.log(y_pred + 1e-9))
    loss = tf.reduce_sum(loss, axis=-1)
    loss = tf.squeeze(loss)
    loss = loss * tf.cast(mask, dtype=tf.float32)
    loss = tf.reduce_sum(loss, axis=-1)
    loss = tf.reduce_mean(loss)
    return loss

# %% [markdown]
# #### Verify whether the loss work as it should

# %%
tmp_pred = tf.one_hot(indices=tf.cast(input_x['input_key'], dtype=tf.int32), depth=VOCAB_SIZE+1)
print(f'tmp_pred.shape={tmp_pred.shape}')
loss(target_x, tmp_pred)
# Out:
# tmp_pred.shape=(1, 2332, 10001)
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>

# %% [markdown]
# #### Verify whether accuracy is working correctly

# %%
accuracy(target_x, tmp_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.0>

# %%
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
def create_model(d_model, n_heads, dropout):

    D_MODEL = d_model

    input_key = Input(shape=[MAX_LEN], batch_size=BATCH_SIZE, dtype=tf.int16, name='input_key')
    input_query = Input(shape=[MAX_LEN], batch_size=BATCH_SIZE, dtype=tf.int16, name='input_query')

    # # Shift Right
    y = Lambda(lambda y: tf.pad(y, paddings=[[0, 0], [1, 0]]))(input_query)

    x = Embedding(input_dim=VOCAB_SIZE, output_dim=D_MODEL)(input_key)
    x += positional_encoding(MAX_LEN, D_MODEL)
    
    y = Embedding(input_dim=VOCAB_SIZE, output_dim=D_MODEL)(y)
    y += positional_encoding(MAX_LEN+1, D_MODEL)

    mask = np.tril(np.ones([1, MAX_LEN+1, MAX_LEN])) # batch_size x (length_of_query+1) x length_of_key

    output = MultiHeadAttention(num_heads=n_heads, key_dim=D_MODEL, value_dim=D_MODEL, 
                                dropout=dropout, use_bias=True)(query=y, value=x)
    
    output = Lambda(lambda x: x[:, :-1])(output)
    output = LayerNormalization(axis=-1)(output)
    output = Dense(VOCAB_SIZE+1, use_bias=True, kernel_regularizer='l2', bias_regularizer='l2')(output)  # 0 for padding, and (1-VOCAB_SIZE) for words

    output = Softmax(axis=-1)(output)
    model = Model(inputs=[input_key, input_query], outputs=output)
    tb_callback = tf.keras.callbacks.TensorBoard('logs_full')
    tb_callback.set_model(model)
#     model.summary()
    return model

# %%
def train(model, epochs, initial_epoch=0):
    
    train_loss_results = []
    train_accuracy_results = []

    vl_loss_results = []
    vl_accuracy_results = []
    
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=1e-4)
    lr_switch = {
                  1: 1e-5, # [20 - 40)
                  2: 1e-6, # [40 - 60)
                  3: 5e-7, # [60 - 80)
                  4: 1e-7, # [80 - 100]
    }
    
    def grad(model, inputs, targets):
        with tf.GradientTape() as tape:
            y_pred = model(inputs)
            loss_value = loss(targets, y_pred)
            acc = accuracy(targets, y_pred)
        return loss_value, acc, tape.gradient(loss_value, model.trainable_variables)
    
    for epoch in range(initial_epoch, epochs):
        epoch_loss_avg = tf.keras.metrics.Mean()
        epoch_accuracy = tf.keras.metrics.Mean()
        
        vl_loss_avg = tf.keras.metrics.Mean()
        vl_accuracy = tf.keras.metrics.Mean()

        for (tk_reviews, mask), _ in zip(train_gen, range(N_TR//BATCH_SIZE)):
            input_dict, target_dict = make_dict(tk_reviews, mask)

            tr_loss, tr_acc, grads = grad(model, input_dict, target_dict)
            optimizer.apply_gradients(zip(grads, model.trainable_variables))

            epoch_loss_avg.update_state(tr_loss)
            epoch_accuracy.update_state(tr_acc)

        tr_avg_loss = epoch_loss_avg.result().numpy()
        tr_avg_acc = epoch_accuracy.result().numpy()
        epoch_loss_avg.reset_states()
        epoch_accuracy.reset_states()

        train_loss_results.append(tr_avg_loss)
        train_accuracy_results.append(tr_avg_acc)
        
        for (tk_reviews, mask), _ in zip(val_gen, range(N_VL//BATCH_SIZE)):
            input_dict, target_dict = make_dict(tk_reviews, mask)
            y_pred = model(input_dict)
            vl_loss = loss(target_dict, y_pred)
            vl_acc = accuracy(target_dict, y_pred)
            
            vl_loss_avg.update_state(vl_loss)
            vl_accuracy.update_state(vl_acc)
        
        vl_loss = vl_loss_avg.result().numpy()
        vl_acc = vl_accuracy.result().numpy()
        vl_loss_avg.reset_states()
        vl_accuracy.reset_states()
        
        vl_loss_results.append(vl_loss)    
        vl_accuracy_results.append(vl_acc)

        print("Epoch %d Loss: %.3f Accuracy: %.3f Val_Loss: %.3f Val_Accuracy: %.3f" %\
                      (epoch, tr_avg_loss, tr_avg_acc, vl_loss, vl_acc))
        
        old_lr = optimizer.learning_rate.numpy()
        if epoch%20 == 0:
            period = old_lr//20
            optimizer.learning_rate.assign(lr_switch.get(period, 1e-4))
            
    return [ np.array(train_loss_results)[..., None], \
             np.array(train_accuracy_results)[..., None], \
             np.array(vl_loss_results)[..., None], \
             np.array(vl_accuracy_results)[..., None] ]

# %%
EPOCHS = 50

# %%
performance = {}

for d_model in [128, 256, 512]:
    for n_heads in [2, 4, 6, 8]:
        for dropout in [0.1, 0.15, 0.2]:
            tmp_model = create_model(d_model=d_model, n_heads=n_heads, dropout=dropout)
            performance[f'{d_model},{n_heads},{dropout}'] = np.hstack(train(tmp_model, epochs=EPOCHS))

perf_file = open('performance_1l.pkl', 'wb')
pickle.dump(performance, perf_file)
perf_file.close()
# Out:
# Epoch 0 Loss: 242.644 Accuracy: 0.055 Val_Loss: 236.806 Val_Accuracy: 0.076
# Epoch 1 Loss: 232.148 Accuracy: 0.055 Val_Loss: 234.053 Val_Accuracy: 0.054
# Epoch 2 Loss: 231.919 Accuracy: 0.055 Val_Loss: 234.038 Val_Accuracy: 0.055
# Epoch 3 Loss: 229.862 Accuracy: 0.060 Val_Loss: 232.382 Val_Accuracy: 0.064
# Epoch 4 Loss: 229.429 Accuracy: 0.065 Val_Loss: 232.826 Val_Accuracy: nan
# Epoch 5 Loss: 228.430 Accuracy: 0.067 Val_Loss: 229.938 Val_Accuracy: 0.070
# Epoch 6 Loss: 225.704 Accuracy: nan Val_Loss: 229.592 Val_Accuracy: 0.069
# Epoch 7 Loss: 226.894 Accuracy: 0.069 Val_Loss: 225.772 Val_Accuracy: 0.087
# Epoch 8 Loss: 226.552 Accuracy: 0.071 Val_Loss: 231.028 Val_Accuracy: 0.086
# Epoch 9 Loss: 223.213 Accuracy: 0.073 Val_Loss: 228.645 Val_Accuracy: 0.072
# Epoch 10 Loss: 224.786 Accuracy: 0.072 Val_Loss: 229.725 Val_Accuracy: 0.074
# Epoch 11 Loss: 224.219 Accuracy: 0.071 Val_Loss: 231.298 Val_Accuracy: 0.076
# Epoch 12 Loss: 224.210 Accuracy: 0.076 Val_Loss: 231.896 Val_Accuracy: 0.077
# Epoch 13 Loss: 223.752 Accuracy: 0.072 Val_Loss: 232.060 Val_Accuracy: 0.077
# Epoch 14 Loss: 223.980 Accuracy: 0.076 Val_Loss: 227.771 Val_Accuracy: 0.075
# Epoch 15 Loss: 221.786 Accuracy: 0.076 Val_Loss: 228.677 Val_Accuracy: 0.078
# Epoch 16 Loss: 223.031 Accuracy: 0.073 Val_Loss: 230.321 Val_Accuracy: 0.079
# Epoch 17 Loss: 223.754 Accuracy: nan Val_Loss: 231.176 Val_Accuracy: 0.080
# Epoch 18 Loss: 222.993 Accuracy: 0.077 Val_Loss: 229.548 Val_Accuracy: 0.087
# Epoch 19 Loss: 224.474 Accuracy: 0.077 Val_Loss: 229.470 Val_Accuracy: 0.083
# Epoch 20 Loss: 221.879 Accuracy: 0.080 Val_Loss: 231.552 Val_Accuracy: 0.082
# Epoch 21 Loss: 221.453 Accuracy: 0.080 Val_Loss: 230.720 Val_Accuracy: 0.080
# Epoch 22 Loss: 223.096 Accuracy: 0.075 Val_Loss: 229.896 Val_Accuracy: nan
# Epoch 23 Loss: 223.912 Accuracy: 0.080 Val_Loss: 232.088 Val_Accuracy: 0.083
# Epoch 24 Loss: 222.709 Accuracy: 0.081 Val_Loss: 229.741 Val_Accuracy: 0.092
# Epoch 25 Loss: 222.914 Accuracy: 0.075 Val_Loss: 229.119 Val_Accuracy: 0.084
# Epoch 26 Loss: 224.113 Accuracy: 0.081 Val_Loss: 228.720 Val_Accuracy: 0.092
# Epoch 27 Loss: 220.904 Accuracy: 0.078 Val_Loss: 230.570 Val_Accuracy: 0.090
# Epoch 28 Loss: 222.641 Accuracy: 0.081 Val_Loss: 227.434 Val_Accuracy: 0.093
# Epoch 29 Loss: 220.304 Accuracy: 0.078 Val_Loss: 228.699 Val_Accuracy: 0.093
# Epoch 30 Loss: 220.146 Accuracy: 0.076 Val_Loss: 230.133 Val_Accuracy: 0.090
# Epoch 31 Loss: 221.875 Accuracy: 0.080 Val_Loss: 229.786 Val_Accuracy: 0.089
# Epoch 32 Loss: 219.758 Accuracy: 0.082 Val_Loss: 227.608 Val_Accuracy: 0.092
# Epoch 33 Loss: 218.854 Accuracy: 0.080 Val_Loss: 231.619 Val_Accuracy: 0.095
# Epoch 34 Loss: 217.550 Accuracy: 0.087 Val_Loss: 228.832 Val_Accuracy: nan
# Epoch 35 Loss: 220.779 Accuracy: 0.085 Val_Loss: 228.895 Val_Accuracy: 0.093
# Epoch 36 Loss: 219.385 Accuracy: 0.088 Val_Loss: 230.407 Val_Accuracy: 0.097
# Epoch 37 Loss: 219.166 Accuracy: nan Val_Loss: 226.607 Val_Accuracy: 0.096
# Epoch 38 Loss: 218.692 Accuracy: 0.091 Val_Loss: 223.800 Val_Accuracy: 0.094
# Epoch 39 Loss: 219.261 Accuracy: 0.092 Val_Loss: 227.048 Val_Accuracy: 0.092
# Epoch 40 Loss: 220.184 Accuracy: 0.091 Val_Loss: 222.475 Val_Accuracy: 0.102
# Epoch 41 Loss: 217.776 Accuracy: 0.088 Val_Loss: 226.668 Val_Accuracy: 0.099
# Epoch 42 Loss: 220.156 Accuracy: 0.090 Val_Loss: 224.215 Val_Accuracy: 0.101
# Epoch 43 Loss: 219.527 Accuracy: 0.094 Val_Loss: 226.052 Val_Accuracy: 0.096
# Epoch 44 Loss: 218.573 Accuracy: 0.092 Val_Loss: 226.189 Val_Accuracy: nan
# Epoch 45 Loss: 216.993 Accuracy: 0.098 Val_Loss: 227.793 Val_Accuracy: 0.105
# Epoch 46 Loss: 216.294 Accuracy: 0.095 Val_Loss: 225.957 Val_Accuracy: 0.104
# Epoch 47 Loss: 215.922 Accuracy: 0.095 Val_Loss: 227.500 Val_Accuracy: 0.103
# Epoch 48 Loss: 216.139 Accuracy: 0.094 Val_Loss: 224.392 Val_Accuracy: 0.109
# Epoch 49 Loss: 217.806 Accuracy: 0.098 Val_Loss: 227.440 Val_Accuracy: 0.101
# Epoch 0 Loss: 247.233 Accuracy: 0.055 Val_Loss: 233.063 Val_Accuracy: 0.053
# Epoch 1 Loss: 230.586 Accuracy: 0.055 Val_Loss: 232.759 Val_Accuracy: 0.053
# Epoch 2 Loss: 230.192 Accuracy: 0.058 Val_Loss: 236.961 Val_Accuracy: 0.079
# Epoch 3 Loss: 227.521 Accuracy: 0.061 Val_Loss: 233.368 Val_Accuracy: 0.082
# Epoch 4 Loss: 228.216 Accuracy: nan Val_Loss: 231.713 Val_Accuracy: 0.069
# Epoch 5 Loss: 226.705 Accuracy: 0.071 Val_Loss: 231.973 Val_Accuracy: nan
# Epoch 6 Loss: 224.439 Accuracy: 0.068 Val_Loss: 229.690 Val_Accuracy: 0.068
# Epoch 7 Loss: 224.135 Accuracy: 0.071 Val_Loss: 228.235 Val_Accuracy: 0.074
# Epoch 8 Loss: 224.037 Accuracy: 0.074 Val_Loss: 231.613 Val_Accuracy: 0.068
# Epoch 9 Loss: 224.408 Accuracy: 0.076 Val_Loss: 230.493 Val_Accuracy: 0.071
# Epoch 10 Loss: 223.730 Accuracy: 0.075 Val_Loss: 229.082 Val_Accuracy: 0.079
# Epoch 11 Loss: 226.025 Accuracy: 0.075 Val_Loss: 226.862 Val_Accuracy: 0.076
# Epoch 12 Loss: 223.214 Accuracy: nan Val_Loss: 229.892 Val_Accuracy: 0.078
# Epoch 13 Loss: 222.205 Accuracy: 0.076 Val_Loss: 229.240 Val_Accuracy: 0.085
# Epoch 14 Loss: 225.860 Accuracy: 0.075 Val_Loss: 230.048 Val_Accuracy: 0.076
# Epoch 15 Loss: 223.136 Accuracy: 0.077 Val_Loss: 230.933 Val_Accuracy: 0.074
# Epoch 16 Loss: 225.777 Accuracy: 0.080 Val_Loss: 232.573 Val_Accuracy: 0.077
# Epoch 17 Loss: 227.550 Accuracy: 0.075 Val_Loss: 229.063 Val_Accuracy: 0.089
# Epoch 18 Loss: 225.427 Accuracy: nan Val_Loss: 228.500 Val_Accuracy: 0.089
# Epoch 19 Loss: 223.424 Accuracy: 0.078 Val_Loss: 228.247 Val_Accuracy: 0.093
# Epoch 20 Loss: 224.032 Accuracy: 0.077 Val_Loss: 230.512 Val_Accuracy: 0.087
# Epoch 21 Loss: 225.111 Accuracy: 0.077 Val_Loss: 227.355 Val_Accuracy: 0.089
# Epoch 22 Loss: 223.272 Accuracy: 0.081 Val_Loss: 232.039 Val_Accuracy: nan
# Epoch 23 Loss: 223.790 Accuracy: 0.081 Val_Loss: 229.247 Val_Accuracy: 0.085
# Epoch 24 Loss: 222.317 Accuracy: 0.080 Val_Loss: 228.980 Val_Accuracy: 0.088
# Epoch 25 Loss: 222.078 Accuracy: 0.078 Val_Loss: 228.105 Val_Accuracy: 0.089
# Epoch 26 Loss: 223.515 Accuracy: 0.077 Val_Loss: 230.974 Val_Accuracy: 0.080
# Epoch 27 Loss: 220.021 Accuracy: 0.076 Val_Loss: 229.415 Val_Accuracy: 0.080
# Epoch 28 Loss: 221.973 Accuracy: 0.081 Val_Loss: 228.309 Val_Accuracy: 0.088
# Epoch 29 Loss: 219.713 Accuracy: 0.080 Val_Loss: 227.717 Val_Accuracy: 0.090
# Epoch 30 Loss: 220.816 Accuracy: 0.083 Val_Loss: 229.388 Val_Accuracy: 0.079
# Epoch 31 Loss: 220.047 Accuracy: 0.080 Val_Loss: 225.549 Val_Accuracy: 0.087
# Epoch 32 Loss: 218.514 Accuracy: nan Val_Loss: 227.450 Val_Accuracy: 0.083
# Epoch 33 Loss: 219.014 Accuracy: 0.085 Val_Loss: 227.238 Val_Accuracy: 0.085
# Epoch 34 Loss: 221.812 Accuracy: 0.081 Val_Loss: 227.040 Val_Accuracy: 0.087
# Epoch 35 Loss: 221.587 Accuracy: 0.083 Val_Loss: 227.088 Val_Accuracy: 0.083
# Epoch 36 Loss: 219.976 Accuracy: 0.081 Val_Loss: 226.926 Val_Accuracy: nan
# Epoch 37 Loss: 218.301 Accuracy: 0.083 Val_Loss: 227.766 Val_Accuracy: 0.094
# Epoch 38 Loss: 221.276 Accuracy: 0.084 Val_Loss: 226.458 Val_Accuracy: 0.082
# Epoch 39 Loss: 218.403 Accuracy: 0.084 Val_Loss: 227.497 Val_Accuracy: 0.091
# Epoch 40 Loss: 216.641 Accuracy: nan Val_Loss: 225.285 Val_Accuracy: 0.089
# Epoch 41 Loss: 216.882 Accuracy: 0.089 Val_Loss: 226.550 Val_Accuracy: 0.085
# Epoch 42 Loss: 216.450 Accuracy: 0.090 Val_Loss: 224.446 Val_Accuracy: 0.088
# Epoch 43 Loss: 218.118 Accuracy: 0.091 Val_Loss: 225.512 Val_Accuracy: 0.095
# Epoch 44 Loss: 217.641 Accuracy: 0.093 Val_Loss: 226.344 Val_Accuracy: 0.106
# Epoch 45 Loss: 217.939 Accuracy: 0.095 Val_Loss: 226.229 Val_Accuracy: 0.100
# Epoch 46 Loss: 217.495 Accuracy: 0.094 Val_Loss: 225.669 Val_Accuracy: 0.100
# Epoch 47 Loss: 217.412 Accuracy: 0.093 Val_Loss: 224.914 Val_Accuracy: 0.101
# Epoch 48 Loss: 216.070 Accuracy: 0.098 Val_Loss: 225.761 Val_Accuracy: 0.097
# Epoch 49 Loss: 217.338 Accuracy: 0.096 Val_Loss: 225.308 Val_Accuracy: 0.105
# Epoch 0 Loss: 244.019 Accuracy: 0.055 Val_Loss: 233.691 Val_Accuracy: 0.055
# Epoch 1 Loss: 233.683 Accuracy: 0.056 Val_Loss: 234.729 Val_Accuracy: 0.054
# Epoch 2 Loss: 231.766 Accuracy: 0.061 Val_Loss: 235.212 Val_Accuracy: nan
# Epoch 3 Loss: 230.482 Accuracy: 0.059 Val_Loss: 233.014 Val_Accuracy: 0.064
# Epoch 4 Loss: 228.190 Accuracy: 0.066 Val_Loss: 233.131 Val_Accuracy: 0.080
# Epoch 5 Loss: 226.340 Accuracy: 0.072 Val_Loss: 229.441 Val_Accuracy: 0.073
# Epoch 6 Loss: 227.611 Accuracy: 0.070 Val_Loss: 231.389 Val_Accuracy: 0.083
# Epoch 7 Loss: 223.782 Accuracy: 0.073 Val_Loss: 230.079 Val_Accuracy: 0.070
# Epoch 8 Loss: 226.499 Accuracy: 0.070 Val_Loss: 229.691 Val_Accuracy: 0.071
# Epoch 9 Loss: 224.543 Accuracy: 0.076 Val_Loss: 228.891 Val_Accuracy: 0.073
# Epoch 10 Loss: 224.310 Accuracy: 0.078 Val_Loss: 228.786 Val_Accuracy: 0.081
# Epoch 11 Loss: 224.360 Accuracy: 0.073 Val_Loss: 229.644 Val_Accuracy: 0.076
# Epoch 12 Loss: 223.174 Accuracy: 0.077 Val_Loss: 228.826 Val_Accuracy: 0.076
# Epoch 13 Loss: 223.329 Accuracy: 0.073 Val_Loss: 229.818 Val_Accuracy: 0.085
# Epoch 14 Loss: 221.540 Accuracy: 0.075 Val_Loss: 231.752 Val_Accuracy: 0.076
# Epoch 15 Loss: 222.526 Accuracy: 0.074 Val_Loss: 230.579 Val_Accuracy: 0.080
# Epoch 16 Loss: 224.075 Accuracy: 0.076 Val_Loss: 227.422 Val_Accuracy: 0.078
# Epoch 17 Loss: 224.004 Accuracy: 0.079 Val_Loss: 228.016 Val_Accuracy: 0.087
# Epoch 18 Loss: 223.316 Accuracy: 0.078 Val_Loss: 231.591 Val_Accuracy: 0.084
# Epoch 19 Loss: 223.907 Accuracy: 0.082 Val_Loss: 230.464 Val_Accuracy: 0.091
# Epoch 20 Loss: 224.134 Accuracy: 0.082 Val_Loss: 231.767 Val_Accuracy: 0.085
# Epoch 21 Loss: 221.985 Accuracy: 0.081 Val_Loss: 229.731 Val_Accuracy: nan
# Epoch 22 Loss: 222.521 Accuracy: 0.082 Val_Loss: 230.529 Val_Accuracy: 0.097
# Epoch 23 Loss: 222.736 Accuracy: 0.080 Val_Loss: 227.046 Val_Accuracy: 0.095
# Epoch 24 Loss: 222.575 Accuracy: 0.082 Val_Loss: 229.295 Val_Accuracy: 0.093
# Epoch 25 Loss: 222.068 Accuracy: nan Val_Loss: 225.495 Val_Accuracy: 0.089
# Epoch 26 Loss: 222.591 Accuracy: 0.082 Val_Loss: 229.680 Val_Accuracy: 0.090
# Epoch 27 Loss: 222.028 Accuracy: 0.082 Val_Loss: 229.341 Val_Accuracy: 0.086
# Epoch 28 Loss: 221.232 Accuracy: 0.077 Val_Loss: 230.068 Val_Accuracy: 0.090
# Epoch 29 Loss: 223.035 Accuracy: 0.081 Val_Loss: 231.512 Val_Accuracy: 0.077
# Epoch 30 Loss: 221.559 Accuracy: 0.080 Val_Loss: 229.928 Val_Accuracy: 0.094
# Epoch 31 Loss: 220.170 Accuracy: 0.080 Val_Loss: 227.759 Val_Accuracy: 0.078
# Epoch 32 Loss: 221.104 Accuracy: 0.078 Val_Loss: 228.606 Val_Accuracy: 0.098
# Epoch 33 Loss: 219.936 Accuracy: 0.079 Val_Loss: 227.240 Val_Accuracy: 0.083
# Epoch 34 Loss: 219.124 Accuracy: 0.080 Val_Loss: 225.088 Val_Accuracy: 0.085
# Epoch 35 Loss: 218.654 Accuracy: 0.083 Val_Loss: 228.577 Val_Accuracy: 0.088
# Epoch 36 Loss: 218.144 Accuracy: 0.084 Val_Loss: 228.254 Val_Accuracy: 0.087
# Epoch 37 Loss: 216.853 Accuracy: 0.085 Val_Loss: 226.957 Val_Accuracy: 0.093
# Epoch 38 Loss: 216.316 Accuracy: 0.086 Val_Loss: 226.562 Val_Accuracy: nan
# Epoch 39 Loss: 218.407 Accuracy: 0.086 Val_Loss: 225.135 Val_Accuracy: nan
# Epoch 40 Loss: 218.818 Accuracy: 0.086 Val_Loss: 227.209 Val_Accuracy: 0.088
# Epoch 41 Loss: 216.852 Accuracy: 0.088 Val_Loss: 224.860 Val_Accuracy: 0.091
# Epoch 42 Loss: 219.768 Accuracy: 0.088 Val_Loss: 229.121 Val_Accuracy: 0.095
# Epoch 43 Loss: 219.314 Accuracy: 0.090 Val_Loss: 228.475 Val_Accuracy: 0.106
# Epoch 44 Loss: 218.660 Accuracy: 0.091 Val_Loss: 226.254 Val_Accuracy: 0.106
# Epoch 45 Loss: 217.180 Accuracy: 0.094 Val_Loss: 226.160 Val_Accuracy: 0.107
# Epoch 46 Loss: 215.124 Accuracy: 0.098 Val_Loss: 228.640 Val_Accuracy: 0.102
# Epoch 47 Loss: 216.342 Accuracy: 0.095 Val_Loss: 224.624 Val_Accuracy: 0.103
# Epoch 48 Loss: 218.475 Accuracy: 0.097 Val_Loss: 224.020 Val_Accuracy: 0.105
# Epoch 49 Loss: 217.195 Accuracy: 0.094 Val_Loss: 228.456 Val_Accuracy: 0.099
# Epoch 0 Loss: 244.170 Accuracy: 0.057 Val_Loss: 234.495 Val_Accuracy: 0.053
# Epoch 1 Loss: 230.629 Accuracy: 0.057 Val_Loss: 232.038 Val_Accuracy: 0.053
# Epoch 2 Loss: 230.304 Accuracy: 0.057 Val_Loss: 231.149 Val_Accuracy: 0.073
# Epoch 3 Loss: 229.679 Accuracy: 0.060 Val_Loss: 230.371 Val_Accuracy: 0.066
# Epoch 4 Loss: 226.258 Accuracy: 0.071 Val_Loss: 230.025 Val_Accuracy: 0.073
# Epoch 5 Loss: 225.798 Accuracy: 0.069 Val_Loss: 227.962 Val_Accuracy: 0.080
# Epoch 6 Loss: 223.703 Accuracy: 0.070 Val_Loss: 231.929 Val_Accuracy: 0.087
# Epoch 7 Loss: 227.488 Accuracy: 0.070 Val_Loss: 228.344 Val_Accuracy: 0.077
# Epoch 8 Loss: 226.955 Accuracy: 0.070 Val_Loss: 230.799 Val_Accuracy: 0.087
# Epoch 9 Loss: 224.670 Accuracy: 0.075 Val_Loss: 228.963 Val_Accuracy: 0.075
# Epoch 10 Loss: 223.859 Accuracy: 0.076 Val_Loss: 228.959 Val_Accuracy: 0.079
# Epoch 11 Loss: 225.357 Accuracy: 0.075 Val_Loss: 228.375 Val_Accuracy: 0.084
# Epoch 12 Loss: 224.528 Accuracy: 0.078 Val_Loss: 226.982 Val_Accuracy: 0.082
# Epoch 13 Loss: 224.423 Accuracy: 0.078 Val_Loss: 231.195 Val_Accuracy: 0.083
# Epoch 14 Loss: 225.888 Accuracy: 0.079 Val_Loss: 228.608 Val_Accuracy: 0.081
# Epoch 15 Loss: 222.664 Accuracy: 0.077 Val_Loss: 228.592 Val_Accuracy: 0.086
# Epoch 16 Loss: 224.307 Accuracy: 0.081 Val_Loss: 230.644 Val_Accuracy: 0.082
# Epoch 17 Loss: 221.585 Accuracy: 0.083 Val_Loss: 232.929 Val_Accuracy: 0.085
# Epoch 18 Loss: 222.063 Accuracy: nan Val_Loss: 231.004 Val_Accuracy: nan
# Epoch 19 Loss: 223.360 Accuracy: 0.080 Val_Loss: 228.579 Val_Accuracy: 0.087
# Epoch 20 Loss: 224.927 Accuracy: 0.080 Val_Loss: 229.983 Val_Accuracy: nan
# Epoch 21 Loss: 221.203 Accuracy: 0.082 Val_Loss: 228.094 Val_Accuracy: 0.087
# Epoch 22 Loss: 221.319 Accuracy: 0.078 Val_Loss: 231.520 Val_Accuracy: 0.084
# Epoch 23 Loss: 223.564 Accuracy: 0.081 Val_Loss: 230.591 Val_Accuracy: 0.088
# Epoch 24 Loss: 223.210 Accuracy: nan Val_Loss: 226.331 Val_Accuracy: 0.092
# Epoch 25 Loss: 221.682 Accuracy: 0.083 Val_Loss: 225.976 Val_Accuracy: 0.092
# Epoch 26 Loss: 222.289 Accuracy: 0.083 Val_Loss: 227.904 Val_Accuracy: 0.089
# Epoch 27 Loss: 219.501 Accuracy: 0.081 Val_Loss: 224.656 Val_Accuracy: 0.094
# Epoch 28 Loss: 216.665 Accuracy: 0.086 Val_Loss: 226.876 Val_Accuracy: 0.096
# Epoch 29 Loss: 221.698 Accuracy: 0.087 Val_Loss: 227.495 Val_Accuracy: 0.095
# Epoch 30 Loss: 220.922 Accuracy: 0.088 Val_Loss: 225.568 Val_Accuracy: 0.098
# Epoch 31 Loss: 221.889 Accuracy: 0.090 Val_Loss: 226.900 Val_Accuracy: 0.096
# Epoch 32 Loss: 218.905 Accuracy: 0.089 Val_Loss: 227.747 Val_Accuracy: 0.090
# Epoch 33 Loss: 218.145 Accuracy: 0.091 Val_Loss: 225.942 Val_Accuracy: 0.098
# Epoch 34 Loss: 218.602 Accuracy: 0.092 Val_Loss: 224.396 Val_Accuracy: 0.105
# Epoch 35 Loss: 219.193 Accuracy: 0.092 Val_Loss: 226.399 Val_Accuracy: 0.104
# Epoch 36 Loss: 218.619 Accuracy: 0.098 Val_Loss: 223.042 Val_Accuracy: 0.105
# Epoch 37 Loss: 217.988 Accuracy: 0.092 Val_Loss: 225.037 Val_Accuracy: 0.109
# Epoch 38 Loss: 217.324 Accuracy: 0.093 Val_Loss: 226.604 Val_Accuracy: 0.105
# Epoch 39 Loss: 215.703 Accuracy: 0.097 Val_Loss: 225.215 Val_Accuracy: 0.105
# Epoch 40 Loss: 219.176 Accuracy: 0.097 Val_Loss: 224.442 Val_Accuracy: 0.102
# Epoch 41 Loss: 217.774 Accuracy: 0.100 Val_Loss: 227.208 Val_Accuracy: nan
# Epoch 42 Loss: 215.384 Accuracy: 0.100 Val_Loss: 223.887 Val_Accuracy: 0.103
# Epoch 43 Loss: 214.674 Accuracy: 0.101 Val_Loss: 225.254 Val_Accuracy: 0.110
# Epoch 44 Loss: 218.229 Accuracy: 0.098 Val_Loss: 226.171 Val_Accuracy: nan
# Epoch 45 Loss: 215.590 Accuracy: 0.104 Val_Loss: 226.282 Val_Accuracy: 0.105
# Epoch 46 Loss: 216.136 Accuracy: 0.104 Val_Loss: 228.701 Val_Accuracy: nan
# Epoch 47 Loss: 215.713 Accuracy: 0.109 Val_Loss: 222.927 Val_Accuracy: 0.110
# Epoch 48 Loss: 215.086 Accuracy: 0.109 Val_Loss: 223.507 Val_Accuracy: 0.116
# Epoch 49 Loss: 215.485 Accuracy: 0.107 Val_Loss: 222.345 Val_Accuracy: 0.113
# Epoch 0 Loss: 247.929 Accuracy: 0.053 Val_Loss: 234.370 Val_Accuracy: 0.055
# Epoch 1 Loss: 232.615 Accuracy: 0.055 Val_Loss: 233.319 Val_Accuracy: 0.050
# Epoch 2 Loss: 230.355 Accuracy: 0.056 Val_Loss: 230.821 Val_Accuracy: nan
# Epoch 3 Loss: 227.357 Accuracy: 0.061 Val_Loss: 234.486 Val_Accuracy: 0.067
# Epoch 4 Loss: 228.381 Accuracy: 0.071 Val_Loss: 228.862 Val_Accuracy: 0.071
# Epoch 5 Loss: 227.747 Accuracy: 0.072 Val_Loss: 230.725 Val_Accuracy: 0.075
# Epoch 6 Loss: 225.846 Accuracy: 0.071 Val_Loss: 231.611 Val_Accuracy: 0.067
# Epoch 7 Loss: 224.856 Accuracy: 0.076 Val_Loss: 228.768 Val_Accuracy: 0.071
# Epoch 8 Loss: 225.229 Accuracy: 0.072 Val_Loss: 229.061 Val_Accuracy: 0.071
# Epoch 9 Loss: 224.141 Accuracy: 0.075 Val_Loss: 228.872 Val_Accuracy: 0.077
# Epoch 10 Loss: 222.118 Accuracy: 0.078 Val_Loss: 229.398 Val_Accuracy: 0.075
# Epoch 11 Loss: 222.370 Accuracy: 0.075 Val_Loss: 231.176 Val_Accuracy: 0.074
# Epoch 12 Loss: 224.960 Accuracy: 0.074 Val_Loss: 230.464 Val_Accuracy: 0.084
# Epoch 13 Loss: 224.023 Accuracy: 0.075 Val_Loss: 229.116 Val_Accuracy: 0.076
# Epoch 14 Loss: 224.351 Accuracy: 0.075 Val_Loss: 231.396 Val_Accuracy: 0.079
# Epoch 15 Loss: 221.082 Accuracy: 0.080 Val_Loss: 231.006 Val_Accuracy: 0.087
# Epoch 16 Loss: 222.471 Accuracy: 0.078 Val_Loss: 227.738 Val_Accuracy: 0.089
# Epoch 17 Loss: 222.400 Accuracy: 0.081 Val_Loss: 227.852 Val_Accuracy: 0.091
# Epoch 18 Loss: 221.158 Accuracy: 0.083 Val_Loss: 232.808 Val_Accuracy: 0.085
# Epoch 19 Loss: 222.229 Accuracy: 0.080 Val_Loss: 231.140 Val_Accuracy: 0.088
# Epoch 20 Loss: 222.935 Accuracy: 0.082 Val_Loss: 227.622 Val_Accuracy: 0.095
# Epoch 21 Loss: 221.918 Accuracy: 0.085 Val_Loss: 229.586 Val_Accuracy: 0.085
# Epoch 22 Loss: 221.230 Accuracy: 0.079 Val_Loss: 227.664 Val_Accuracy: 0.093
# Epoch 23 Loss: 221.199 Accuracy: 0.081 Val_Loss: 230.617 Val_Accuracy: 0.099
# Epoch 24 Loss: 221.782 Accuracy: 0.081 Val_Loss: 231.438 Val_Accuracy: 0.089
# Epoch 25 Loss: 220.733 Accuracy: 0.080 Val_Loss: 229.218 Val_Accuracy: 0.090
# Epoch 26 Loss: 221.820 Accuracy: 0.084 Val_Loss: 230.333 Val_Accuracy: 0.102
# Epoch 27 Loss: 221.088 Accuracy: 0.086 Val_Loss: 226.536 Val_Accuracy: 0.094
# Epoch 28 Loss: 219.858 Accuracy: 0.088 Val_Loss: 227.208 Val_Accuracy: 0.105
# Epoch 29 Loss: 219.162 Accuracy: 0.088 Val_Loss: 228.821 Val_Accuracy: 0.097
# Epoch 30 Loss: 219.307 Accuracy: 0.089 Val_Loss: 228.237 Val_Accuracy: 0.097
# Epoch 31 Loss: 219.803 Accuracy: 0.092 Val_Loss: 227.528 Val_Accuracy: nan
# Epoch 32 Loss: 219.338 Accuracy: 0.095 Val_Loss: 225.615 Val_Accuracy: 0.101
# Epoch 33 Loss: 216.918 Accuracy: 0.094 Val_Loss: 228.208 Val_Accuracy: 0.098
# Epoch 34 Loss: 216.643 Accuracy: 0.097 Val_Loss: 227.014 Val_Accuracy: 0.100
# Epoch 35 Loss: 219.162 Accuracy: 0.094 Val_Loss: 230.373 Val_Accuracy: 0.102
# Epoch 36 Loss: 218.920 Accuracy: 0.096 Val_Loss: 225.544 Val_Accuracy: 0.102
# Epoch 37 Loss: 217.978 Accuracy: 0.097 Val_Loss: 227.287 Val_Accuracy: 0.102
# Epoch 38 Loss: 217.162 Accuracy: 0.094 Val_Loss: 225.278 Val_Accuracy: 0.108
# Epoch 39 Loss: 218.096 Accuracy: 0.096 Val_Loss: 224.390 Val_Accuracy: nan
# Epoch 40 Loss: 216.038 Accuracy: 0.098 Val_Loss: 226.884 Val_Accuracy: 0.102
# Epoch 41 Loss: 217.508 Accuracy: 0.099 Val_Loss: 227.037 Val_Accuracy: 0.106
# Epoch 42 Loss: 218.606 Accuracy: 0.099 Val_Loss: 227.463 Val_Accuracy: 0.105
# Epoch 43 Loss: 218.102 Accuracy: 0.102 Val_Loss: 223.137 Val_Accuracy: 0.110
# Epoch 44 Loss: 217.226 Accuracy: 0.100 Val_Loss: 224.108 Val_Accuracy: 0.108
# Epoch 45 Loss: 217.131 Accuracy: 0.102 Val_Loss: 228.292 Val_Accuracy: 0.105
# Epoch 46 Loss: 215.305 Accuracy: 0.103 Val_Loss: 223.869 Val_Accuracy: 0.110
# Epoch 47 Loss: 217.906 Accuracy: 0.102 Val_Loss: 225.681 Val_Accuracy: 0.110
# Epoch 48 Loss: 217.592 Accuracy: 0.104 Val_Loss: 222.242 Val_Accuracy: nan
# Epoch 49 Loss: 214.392 Accuracy: 0.106 Val_Loss: 224.393 Val_Accuracy: 0.111
# Epoch 0 Loss: 244.990 Accuracy: 0.054 Val_Loss: 233.149 Val_Accuracy: 0.055
# Epoch 1 Loss: 231.475 Accuracy: 0.055 Val_Loss: 232.275 Val_Accuracy: 0.055
# Epoch 2 Loss: 231.141 Accuracy: 0.057 Val_Loss: 234.999 Val_Accuracy: 0.082
# Epoch 3 Loss: 228.833 Accuracy: 0.061 Val_Loss: 229.458 Val_Accuracy: 0.070
# Epoch 4 Loss: 228.046 Accuracy: 0.067 Val_Loss: 227.351 Val_Accuracy: 0.073
# Epoch 5 Loss: 228.322 Accuracy: 0.074 Val_Loss: 230.165 Val_Accuracy: 0.071
# Epoch 6 Loss: 225.031 Accuracy: 0.069 Val_Loss: 229.283 Val_Accuracy: nan
# Epoch 7 Loss: 226.125 Accuracy: 0.071 Val_Loss: 229.116 Val_Accuracy: 0.082
# Epoch 8 Loss: 224.210 Accuracy: 0.073 Val_Loss: 228.362 Val_Accuracy: 0.070
# Epoch 9 Loss: 224.870 Accuracy: 0.075 Val_Loss: 227.890 Val_Accuracy: 0.076
# Epoch 10 Loss: 223.153 Accuracy: 0.076 Val_Loss: 231.871 Val_Accuracy: nan
# Epoch 11 Loss: 222.240 Accuracy: 0.072 Val_Loss: 231.099 Val_Accuracy: 0.073
# Epoch 12 Loss: 222.994 Accuracy: 0.077 Val_Loss: 229.962 Val_Accuracy: 0.072
# Epoch 13 Loss: 225.600 Accuracy: 0.074 Val_Loss: 231.082 Val_Accuracy: 0.078
# Epoch 14 Loss: 226.053 Accuracy: 0.076 Val_Loss: 229.665 Val_Accuracy: 0.086
# Epoch 15 Loss: 222.790 Accuracy: 0.075 Val_Loss: 228.821 Val_Accuracy: 0.089
# Epoch 16 Loss: 223.154 Accuracy: 0.075 Val_Loss: 226.600 Val_Accuracy: 0.089
# Epoch 17 Loss: 224.617 Accuracy: 0.075 Val_Loss: 227.571 Val_Accuracy: 0.087
# Epoch 18 Loss: 220.639 Accuracy: 0.079 Val_Loss: 228.440 Val_Accuracy: 0.086
# Epoch 19 Loss: 223.780 Accuracy: 0.079 Val_Loss: 230.273 Val_Accuracy: 0.084
# Epoch 20 Loss: 223.275 Accuracy: 0.081 Val_Loss: 226.721 Val_Accuracy: 0.095
# Epoch 21 Loss: 221.304 Accuracy: 0.080 Val_Loss: 226.989 Val_Accuracy: 0.085
# Epoch 22 Loss: 220.739 Accuracy: 0.079 Val_Loss: 227.756 Val_Accuracy: 0.098
# Epoch 23 Loss: 223.523 Accuracy: 0.082 Val_Loss: 228.157 Val_Accuracy: 0.091
# Epoch 24 Loss: 218.889 Accuracy: 0.086 Val_Loss: 227.586 Val_Accuracy: 0.094
# Epoch 25 Loss: 221.420 Accuracy: 0.087 Val_Loss: 227.661 Val_Accuracy: 0.093
# Epoch 26 Loss: 220.114 Accuracy: 0.092 Val_Loss: 226.124 Val_Accuracy: 0.100
# Epoch 27 Loss: 220.881 Accuracy: 0.090 Val_Loss: 227.370 Val_Accuracy: 0.096
# Epoch 28 Loss: 216.524 Accuracy: 0.093 Val_Loss: 228.497 Val_Accuracy: 0.095
# Epoch 29 Loss: 220.232 Accuracy: 0.087 Val_Loss: 227.720 Val_Accuracy: 0.105
# Epoch 30 Loss: 220.098 Accuracy: nan Val_Loss: 224.717 Val_Accuracy: 0.098
# Epoch 31 Loss: 219.263 Accuracy: 0.093 Val_Loss: 225.313 Val_Accuracy: 0.102
# Epoch 32 Loss: 219.363 Accuracy: 0.090 Val_Loss: 227.092 Val_Accuracy: 0.096
# Epoch 33 Loss: 218.468 Accuracy: 0.096 Val_Loss: 226.249 Val_Accuracy: 0.105
# Epoch 34 Loss: 217.805 Accuracy: 0.095 Val_Loss: 224.902 Val_Accuracy: 0.101
# Epoch 35 Loss: 216.636 Accuracy: 0.093 Val_Loss: 227.128 Val_Accuracy: 0.102
# Epoch 36 Loss: 217.494 Accuracy: 0.094 Val_Loss: 226.236 Val_Accuracy: 0.101
# Epoch 37 Loss: 218.608 Accuracy: 0.098 Val_Loss: 223.824 Val_Accuracy: 0.105
# Epoch 38 Loss: 218.155 Accuracy: 0.100 Val_Loss: 226.271 Val_Accuracy: 0.105
# Epoch 39 Loss: 216.304 Accuracy: 0.100 Val_Loss: 228.826 Val_Accuracy: 0.101
# Epoch 40 Loss: 217.375 Accuracy: 0.101 Val_Loss: 220.685 Val_Accuracy: nan
# Epoch 41 Loss: 217.587 Accuracy: 0.097 Val_Loss: 225.141 Val_Accuracy: 0.103
# Epoch 42 Loss: 217.135 Accuracy: 0.099 Val_Loss: 224.255 Val_Accuracy: 0.105
# Epoch 43 Loss: 215.053 Accuracy: 0.099 Val_Loss: 223.045 Val_Accuracy: 0.105
# Epoch 44 Loss: 216.840 Accuracy: 0.104 Val_Loss: 224.344 Val_Accuracy: nan
# Epoch 45 Loss: 215.218 Accuracy: 0.104 Val_Loss: 221.362 Val_Accuracy: nan
# Epoch 46 Loss: 216.051 Accuracy: 0.105 Val_Loss: 223.455 Val_Accuracy: 0.112
# Epoch 47 Loss: 217.207 Accuracy: 0.107 Val_Loss: 224.092 Val_Accuracy: 0.115
# Epoch 48 Loss: 217.086 Accuracy: 0.104 Val_Loss: 224.745 Val_Accuracy: 0.111
# Epoch 49 Loss: 217.290 Accuracy: 0.105 Val_Loss: 223.340 Val_Accuracy: 0.111
# Epoch 0 Loss: 247.006 Accuracy: 0.054 Val_Loss: 234.592 Val_Accuracy: 0.053
# Epoch 1 Loss: 231.741 Accuracy: nan Val_Loss: 237.900 Val_Accuracy: nan
# Epoch 2 Loss: 230.101 Accuracy: 0.058 Val_Loss: 233.615 Val_Accuracy: nan
# Epoch 3 Loss: 230.024 Accuracy: 0.059 Val_Loss: 231.009 Val_Accuracy: 0.063
# Epoch 4 Loss: 227.378 Accuracy: 0.066 Val_Loss: 228.214 Val_Accuracy: 0.073
# Epoch 5 Loss: 226.081 Accuracy: 0.071 Val_Loss: 230.013 Val_Accuracy: 0.083
# Epoch 6 Loss: 226.531 Accuracy: 0.073 Val_Loss: 231.004 Val_Accuracy: 0.075
# Epoch 7 Loss: 224.794 Accuracy: 0.074 Val_Loss: 229.479 Val_Accuracy: 0.080
# Epoch 8 Loss: 222.459 Accuracy: 0.076 Val_Loss: 230.012 Val_Accuracy: 0.076
# Epoch 9 Loss: 224.840 Accuracy: 0.075 Val_Loss: 228.282 Val_Accuracy: nan
# Epoch 10 Loss: 225.306 Accuracy: 0.074 Val_Loss: 229.699 Val_Accuracy: 0.075
# Epoch 11 Loss: 224.296 Accuracy: 0.075 Val_Loss: 228.714 Val_Accuracy: nan
# Epoch 12 Loss: 224.737 Accuracy: 0.075 Val_Loss: 228.559 Val_Accuracy: 0.074
# Epoch 13 Loss: 224.220 Accuracy: 0.078 Val_Loss: 229.986 Val_Accuracy: 0.083
# Epoch 14 Loss: 223.933 Accuracy: 0.073 Val_Loss: 232.432 Val_Accuracy: 0.076
# Epoch 15 Loss: 221.453 Accuracy: 0.074 Val_Loss: 231.614 Val_Accuracy: 0.077
# Epoch 16 Loss: 223.308 Accuracy: 0.079 Val_Loss: 232.350 Val_Accuracy: 0.081
# Epoch 17 Loss: 224.767 Accuracy: 0.076 Val_Loss: 229.066 Val_Accuracy: 0.082
# Epoch 18 Loss: 223.067 Accuracy: 0.080 Val_Loss: 226.720 Val_Accuracy: 0.084
# Epoch 19 Loss: 221.190 Accuracy: 0.078 Val_Loss: 232.912 Val_Accuracy: nan
# Epoch 20 Loss: 223.239 Accuracy: 0.086 Val_Loss: 225.907 Val_Accuracy: 0.092
# Epoch 21 Loss: 220.756 Accuracy: 0.083 Val_Loss: 229.802 Val_Accuracy: 0.084
# Epoch 22 Loss: 222.369 Accuracy: nan Val_Loss: 226.840 Val_Accuracy: nan
# Epoch 23 Loss: 220.136 Accuracy: 0.084 Val_Loss: 226.758 Val_Accuracy: 0.092
# Epoch 24 Loss: 220.008 Accuracy: 0.090 Val_Loss: 221.412 Val_Accuracy: 0.095
# Epoch 25 Loss: 221.699 Accuracy: 0.086 Val_Loss: 226.207 Val_Accuracy: 0.097
# Epoch 26 Loss: 221.204 Accuracy: 0.086 Val_Loss: 223.858 Val_Accuracy: 0.100
# Epoch 27 Loss: 219.637 Accuracy: 0.088 Val_Loss: 223.727 Val_Accuracy: 0.100
# Epoch 28 Loss: 218.549 Accuracy: 0.090 Val_Loss: 226.333 Val_Accuracy: 0.096
# Epoch 29 Loss: 219.145 Accuracy: 0.092 Val_Loss: 227.411 Val_Accuracy: 0.101
# Epoch 30 Loss: 216.929 Accuracy: 0.093 Val_Loss: 225.524 Val_Accuracy: 0.098
# Epoch 31 Loss: 216.898 Accuracy: 0.093 Val_Loss: 225.519 Val_Accuracy: 0.100
# Epoch 32 Loss: 217.098 Accuracy: 0.095 Val_Loss: 225.495 Val_Accuracy: 0.105
# Epoch 33 Loss: 218.060 Accuracy: 0.094 Val_Loss: 224.325 Val_Accuracy: 0.103
# Epoch 34 Loss: 218.649 Accuracy: 0.096 Val_Loss: 225.291 Val_Accuracy: 0.107
# Epoch 35 Loss: 218.438 Accuracy: 0.099 Val_Loss: 225.730 Val_Accuracy: 0.106
# Epoch 36 Loss: 219.597 Accuracy: 0.097 Val_Loss: 226.303 Val_Accuracy: 0.106
# Epoch 37 Loss: 214.774 Accuracy: 0.100 Val_Loss: 220.227 Val_Accuracy: 0.108
# Epoch 38 Loss: 217.282 Accuracy: 0.100 Val_Loss: 228.474 Val_Accuracy: 0.096
# Epoch 39 Loss: 216.101 Accuracy: 0.100 Val_Loss: 223.847 Val_Accuracy: 0.105
# Epoch 40 Loss: 216.724 Accuracy: 0.104 Val_Loss: 224.673 Val_Accuracy: 0.105
# Epoch 41 Loss: 217.930 Accuracy: 0.104 Val_Loss: 225.676 Val_Accuracy: 0.111
# Epoch 42 Loss: 215.208 Accuracy: 0.105 Val_Loss: 223.428 Val_Accuracy: 0.116
# Epoch 43 Loss: 216.369 Accuracy: 0.110 Val_Loss: 223.738 Val_Accuracy: 0.114
# Epoch 44 Loss: 213.672 Accuracy: 0.107 Val_Loss: 222.701 Val_Accuracy: 0.114
# Epoch 45 Loss: 216.534 Accuracy: 0.110 Val_Loss: 223.103 Val_Accuracy: 0.110
# Epoch 46 Loss: 216.405 Accuracy: 0.110 Val_Loss: 223.674 Val_Accuracy: 0.116
# Epoch 47 Loss: 214.513 Accuracy: 0.107 Val_Loss: 225.926 Val_Accuracy: 0.112
# Epoch 48 Loss: 216.400 Accuracy: nan Val_Loss: 222.164 Val_Accuracy: 0.120
# Epoch 49 Loss: 214.469 Accuracy: nan Val_Loss: 223.744 Val_Accuracy: 0.116
# Epoch 0 Loss: 245.429 Accuracy: 0.053 Val_Loss: 233.826 Val_Accuracy: 0.051
# Epoch 1 Loss: 232.869 Accuracy: 0.053 Val_Loss: 234.664 Val_Accuracy: 0.053
# Epoch 2 Loss: 228.600 Accuracy: 0.056 Val_Loss: 234.919 Val_Accuracy: nan
# Epoch 3 Loss: 229.520 Accuracy: 0.062 Val_Loss: 233.839 Val_Accuracy: 0.060
# Epoch 4 Loss: 226.884 Accuracy: 0.064 Val_Loss: 230.371 Val_Accuracy: 0.067
# Epoch 5 Loss: 224.923 Accuracy: nan Val_Loss: 228.484 Val_Accuracy: 0.068
# Epoch 6 Loss: 227.072 Accuracy: 0.069 Val_Loss: 228.466 Val_Accuracy: 0.072
# Epoch 7 Loss: 224.656 Accuracy: 0.071 Val_Loss: 230.183 Val_Accuracy: 0.077
# Epoch 8 Loss: 224.405 Accuracy: 0.076 Val_Loss: 228.690 Val_Accuracy: 0.081
# Epoch 9 Loss: 224.251 Accuracy: 0.073 Val_Loss: 230.430 Val_Accuracy: 0.078
# Epoch 10 Loss: 223.456 Accuracy: 0.075 Val_Loss: 231.110 Val_Accuracy: 0.073
# Epoch 11 Loss: 224.926 Accuracy: 0.077 Val_Loss: 229.829 Val_Accuracy: 0.078
# Epoch 12 Loss: 223.185 Accuracy: 0.076 Val_Loss: 228.840 Val_Accuracy: 0.084
# Epoch 13 Loss: 224.137 Accuracy: 0.080 Val_Loss: 226.913 Val_Accuracy: 0.083
# Epoch 14 Loss: 222.823 Accuracy: 0.077 Val_Loss: 228.353 Val_Accuracy: 0.090
# Epoch 15 Loss: 221.416 Accuracy: 0.075 Val_Loss: 228.150 Val_Accuracy: 0.085
# Epoch 16 Loss: 222.566 Accuracy: 0.079 Val_Loss: 228.258 Val_Accuracy: 0.088
# Epoch 17 Loss: 221.446 Accuracy: 0.081 Val_Loss: 229.897 Val_Accuracy: 0.094
# Epoch 18 Loss: 224.842 Accuracy: 0.079 Val_Loss: 226.925 Val_Accuracy: 0.091
# Epoch 19 Loss: 224.428 Accuracy: 0.083 Val_Loss: 229.292 Val_Accuracy: 0.088
# Epoch 20 Loss: 223.313 Accuracy: 0.082 Val_Loss: 227.626 Val_Accuracy: 0.096
# Epoch 21 Loss: 223.040 Accuracy: 0.080 Val_Loss: 226.992 Val_Accuracy: 0.091
# Epoch 22 Loss: 220.737 Accuracy: 0.084 Val_Loss: 228.107 Val_Accuracy: 0.093
# Epoch 23 Loss: 220.725 Accuracy: 0.084 Val_Loss: 226.859 Val_Accuracy: 0.093
# Epoch 24 Loss: 218.142 Accuracy: 0.085 Val_Loss: 231.127 Val_Accuracy: 0.091
# Epoch 25 Loss: 222.808 Accuracy: 0.086 Val_Loss: 232.860 Val_Accuracy: 0.089
# Epoch 26 Loss: 218.386 Accuracy: 0.083 Val_Loss: 227.228 Val_Accuracy: 0.099
# Epoch 27 Loss: 220.598 Accuracy: 0.084 Val_Loss: 224.577 Val_Accuracy: 0.096
# Epoch 28 Loss: 220.100 Accuracy: 0.088 Val_Loss: 225.030 Val_Accuracy: 0.099
# Epoch 29 Loss: 218.395 Accuracy: 0.091 Val_Loss: 224.868 Val_Accuracy: 0.092
# Epoch 30 Loss: 219.584 Accuracy: 0.091 Val_Loss: 223.987 Val_Accuracy: 0.100
# Epoch 31 Loss: 218.109 Accuracy: 0.093 Val_Loss: 228.426 Val_Accuracy: 0.091
# Epoch 32 Loss: 218.327 Accuracy: 0.094 Val_Loss: 229.080 Val_Accuracy: 0.092
# Epoch 33 Loss: 216.997 Accuracy: 0.094 Val_Loss: 224.794 Val_Accuracy: 0.097
# Epoch 34 Loss: 217.259 Accuracy: 0.096 Val_Loss: 223.656 Val_Accuracy: 0.102
# Epoch 35 Loss: 219.417 Accuracy: 0.097 Val_Loss: 222.967 Val_Accuracy: 0.101
# Epoch 36 Loss: 217.364 Accuracy: 0.098 Val_Loss: 225.196 Val_Accuracy: 0.107
# Epoch 37 Loss: 217.840 Accuracy: 0.094 Val_Loss: 224.978 Val_Accuracy: 0.106
# Epoch 38 Loss: 219.577 Accuracy: nan Val_Loss: 224.869 Val_Accuracy: 0.102
# Epoch 39 Loss: 218.458 Accuracy: 0.096 Val_Loss: 225.526 Val_Accuracy: 0.106
# Epoch 40 Loss: 218.617 Accuracy: 0.099 Val_Loss: 223.876 Val_Accuracy: 0.107
# Epoch 41 Loss: 219.350 Accuracy: 0.097 Val_Loss: 220.966 Val_Accuracy: 0.107
# Epoch 42 Loss: 216.273 Accuracy: 0.105 Val_Loss: 226.568 Val_Accuracy: 0.108
# Epoch 43 Loss: 214.134 Accuracy: 0.101 Val_Loss: 225.484 Val_Accuracy: nan
# Epoch 44 Loss: 217.618 Accuracy: 0.100 Val_Loss: 225.659 Val_Accuracy: 0.101
# Epoch 45 Loss: 214.303 Accuracy: nan Val_Loss: 224.130 Val_Accuracy: 0.107
# Epoch 46 Loss: 215.255 Accuracy: 0.100 Val_Loss: 225.261 Val_Accuracy: 0.113
# Epoch 47 Loss: 215.865 Accuracy: 0.104 Val_Loss: 224.130 Val_Accuracy: 0.108
# Epoch 48 Loss: 216.090 Accuracy: 0.102 Val_Loss: 227.039 Val_Accuracy: 0.109
# Epoch 49 Loss: 216.575 Accuracy: 0.104 Val_Loss: 224.214 Val_Accuracy: 0.109
# Epoch 0 Loss: 243.687 Accuracy: 0.051 Val_Loss: 238.291 Val_Accuracy: nan
# Epoch 1 Loss: 230.323 Accuracy: 0.056 Val_Loss: 231.842 Val_Accuracy: 0.054
# Epoch 2 Loss: 228.875 Accuracy: 0.059 Val_Loss: 234.507 Val_Accuracy: 0.066
# Epoch 3 Loss: 228.432 Accuracy: 0.060 Val_Loss: 229.594 Val_Accuracy: 0.070
# Epoch 4 Loss: 228.030 Accuracy: 0.067 Val_Loss: 228.509 Val_Accuracy: 0.079
# Epoch 5 Loss: 225.883 Accuracy: 0.072 Val_Loss: 231.118 Val_Accuracy: 0.073
# Epoch 6 Loss: 226.574 Accuracy: 0.069 Val_Loss: 229.928 Val_Accuracy: 0.090
# Epoch 7 Loss: 226.000 Accuracy: 0.077 Val_Loss: 228.825 Val_Accuracy: 0.075
# Epoch 8 Loss: 224.011 Accuracy: nan Val_Loss: 231.419 Val_Accuracy: 0.075
# Epoch 9 Loss: 225.705 Accuracy: 0.073 Val_Loss: 228.408 Val_Accuracy: 0.085
# Epoch 10 Loss: 222.217 Accuracy: 0.078 Val_Loss: 229.977 Val_Accuracy: 0.083
# Epoch 11 Loss: 222.751 Accuracy: 0.076 Val_Loss: 230.202 Val_Accuracy: 0.078
# Epoch 12 Loss: 225.398 Accuracy: 0.072 Val_Loss: 230.229 Val_Accuracy: 0.076
# Epoch 13 Loss: 223.692 Accuracy: 0.078 Val_Loss: 230.927 Val_Accuracy: 0.084
# Epoch 14 Loss: 224.366 Accuracy: 0.077 Val_Loss: 231.430 Val_Accuracy: 0.086
# Epoch 15 Loss: 223.975 Accuracy: 0.077 Val_Loss: 227.318 Val_Accuracy: 0.088
# Epoch 16 Loss: 225.284 Accuracy: 0.079 Val_Loss: 228.685 Val_Accuracy: 0.093
# Epoch 17 Loss: 221.553 Accuracy: 0.080 Val_Loss: 226.692 Val_Accuracy: 0.093
# Epoch 18 Loss: 223.476 Accuracy: 0.080 Val_Loss: 226.651 Val_Accuracy: 0.091
# Epoch 19 Loss: 222.822 Accuracy: 0.080 Val_Loss: 229.054 Val_Accuracy: 0.084
# Epoch 20 Loss: 223.309 Accuracy: 0.079 Val_Loss: 227.264 Val_Accuracy: 0.093
# Epoch 21 Loss: 220.454 Accuracy: 0.081 Val_Loss: 230.188 Val_Accuracy: nan
# Epoch 22 Loss: 219.635 Accuracy: 0.082 Val_Loss: 232.462 Val_Accuracy: 0.090
# Epoch 23 Loss: 221.535 Accuracy: 0.083 Val_Loss: 228.161 Val_Accuracy: 0.091
# Epoch 24 Loss: 220.946 Accuracy: 0.085 Val_Loss: 228.448 Val_Accuracy: 0.089
# Epoch 25 Loss: 220.716 Accuracy: 0.086 Val_Loss: 226.730 Val_Accuracy: 0.094
# Epoch 26 Loss: 221.202 Accuracy: 0.085 Val_Loss: 229.973 Val_Accuracy: 0.094
# Epoch 27 Loss: 218.538 Accuracy: 0.089 Val_Loss: 224.186 Val_Accuracy: 0.091
# Epoch 28 Loss: 219.416 Accuracy: 0.086 Val_Loss: 225.514 Val_Accuracy: 0.101
# Epoch 29 Loss: 219.658 Accuracy: 0.092 Val_Loss: 225.921 Val_Accuracy: 0.096
# Epoch 30 Loss: 218.348 Accuracy: 0.090 Val_Loss: 226.881 Val_Accuracy: 0.099
# Epoch 31 Loss: 218.629 Accuracy: 0.096 Val_Loss: 225.605 Val_Accuracy: 0.101
# Epoch 32 Loss: 219.412 Accuracy: 0.097 Val_Loss: 224.417 Val_Accuracy: 0.100
# Epoch 33 Loss: 218.294 Accuracy: 0.096 Val_Loss: 225.448 Val_Accuracy: 0.102
# Epoch 34 Loss: 218.687 Accuracy: 0.094 Val_Loss: 225.617 Val_Accuracy: 0.103
# Epoch 35 Loss: 218.320 Accuracy: 0.094 Val_Loss: 227.060 Val_Accuracy: 0.102
# Epoch 36 Loss: 217.206 Accuracy: 0.093 Val_Loss: 224.732 Val_Accuracy: 0.106
# Epoch 37 Loss: 219.153 Accuracy: 0.096 Val_Loss: 228.507 Val_Accuracy: 0.101
# Epoch 38 Loss: 218.009 Accuracy: 0.098 Val_Loss: 224.513 Val_Accuracy: 0.105
# Epoch 39 Loss: 217.197 Accuracy: 0.101 Val_Loss: 223.919 Val_Accuracy: 0.115
# Epoch 40 Loss: 215.501 Accuracy: 0.101 Val_Loss: 227.254 Val_Accuracy: 0.107
# Epoch 41 Loss: 217.797 Accuracy: 0.100 Val_Loss: 227.010 Val_Accuracy: 0.112
# Epoch 42 Loss: 217.434 Accuracy: 0.103 Val_Loss: 224.733 Val_Accuracy: 0.111
# Epoch 43 Loss: 215.072 Accuracy: 0.104 Val_Loss: 229.383 Val_Accuracy: 0.111
# Epoch 44 Loss: 214.263 Accuracy: 0.104 Val_Loss: 228.864 Val_Accuracy: 0.116
# Epoch 45 Loss: 215.511 Accuracy: 0.102 Val_Loss: 223.124 Val_Accuracy: 0.116
# Epoch 46 Loss: 216.968 Accuracy: 0.104 Val_Loss: 226.023 Val_Accuracy: 0.117
# Epoch 47 Loss: 216.626 Accuracy: 0.108 Val_Loss: 223.149 Val_Accuracy: 0.116
# Epoch 48 Loss: 216.982 Accuracy: 0.106 Val_Loss: 226.187 Val_Accuracy: 0.114
# Epoch 49 Loss: 218.836 Accuracy: 0.110 Val_Loss: 222.831 Val_Accuracy: 0.117
# Epoch 0 Loss: 243.813 Accuracy: 0.050 Val_Loss: 234.703 Val_Accuracy: 0.075
# Epoch 1 Loss: 233.065 Accuracy: 0.055 Val_Loss: 236.069 Val_Accuracy: 0.054
# Epoch 2 Loss: 232.744 Accuracy: 0.058 Val_Loss: 229.718 Val_Accuracy: 0.073
# Epoch 3 Loss: 230.402 Accuracy: nan Val_Loss: 230.430 Val_Accuracy: 0.066
# Epoch 4 Loss: 226.465 Accuracy: 0.068 Val_Loss: 231.245 Val_Accuracy: 0.089
# Epoch 5 Loss: 225.284 Accuracy: 0.070 Val_Loss: 230.222 Val_Accuracy: nan
# Epoch 6 Loss: 225.047 Accuracy: 0.072 Val_Loss: 228.890 Val_Accuracy: 0.092
# Epoch 7 Loss: 224.245 Accuracy: 0.070 Val_Loss: 230.888 Val_Accuracy: 0.077
# Epoch 8 Loss: 224.142 Accuracy: 0.075 Val_Loss: 229.103 Val_Accuracy: 0.075
# Epoch 9 Loss: 225.784 Accuracy: 0.078 Val_Loss: 227.702 Val_Accuracy: 0.074
# Epoch 10 Loss: 223.330 Accuracy: 0.076 Val_Loss: 228.877 Val_Accuracy: 0.070
# Epoch 11 Loss: 224.890 Accuracy: 0.074 Val_Loss: 229.843 Val_Accuracy: 0.077
# Epoch 12 Loss: 225.234 Accuracy: 0.076 Val_Loss: 228.306 Val_Accuracy: nan
# Epoch 13 Loss: 223.332 Accuracy: 0.078 Val_Loss: 229.688 Val_Accuracy: 0.074
# Epoch 14 Loss: 222.567 Accuracy: 0.077 Val_Loss: 230.790 Val_Accuracy: 0.086
# Epoch 15 Loss: 221.581 Accuracy: 0.081 Val_Loss: 227.200 Val_Accuracy: 0.092
# Epoch 16 Loss: 224.936 Accuracy: 0.081 Val_Loss: 228.515 Val_Accuracy: 0.092
# Epoch 17 Loss: 223.598 Accuracy: 0.080 Val_Loss: 226.454 Val_Accuracy: 0.085
# Epoch 18 Loss: 222.350 Accuracy: 0.078 Val_Loss: 232.569 Val_Accuracy: 0.089
# Epoch 19 Loss: 222.967 Accuracy: 0.084 Val_Loss: 225.529 Val_Accuracy: 0.092
# Epoch 20 Loss: 221.582 Accuracy: 0.083 Val_Loss: 229.960 Val_Accuracy: 0.091
# Epoch 21 Loss: 224.461 Accuracy: 0.083 Val_Loss: 229.357 Val_Accuracy: 0.088
# Epoch 22 Loss: 222.744 Accuracy: 0.083 Val_Loss: 225.225 Val_Accuracy: 0.093
# Epoch 23 Loss: 221.761 Accuracy: 0.082 Val_Loss: 229.247 Val_Accuracy: 0.092
# Epoch 24 Loss: 219.205 Accuracy: 0.088 Val_Loss: 226.449 Val_Accuracy: 0.099
# Epoch 25 Loss: 219.792 Accuracy: 0.089 Val_Loss: 227.793 Val_Accuracy: 0.092
# Epoch 26 Loss: 218.684 Accuracy: 0.087 Val_Loss: 231.310 Val_Accuracy: 0.091
# Epoch 27 Loss: 219.530 Accuracy: 0.087 Val_Loss: 232.887 Val_Accuracy: nan
# Epoch 28 Loss: 219.825 Accuracy: 0.090 Val_Loss: 225.186 Val_Accuracy: 0.097
# Epoch 29 Loss: 221.498 Accuracy: 0.089 Val_Loss: 226.309 Val_Accuracy: 0.096
# Epoch 30 Loss: 217.022 Accuracy: 0.092 Val_Loss: 224.755 Val_Accuracy: 0.095
# Epoch 31 Loss: 217.272 Accuracy: 0.093 Val_Loss: 222.032 Val_Accuracy: 0.100
# Epoch 32 Loss: 217.487 Accuracy: 0.092 Val_Loss: 228.201 Val_Accuracy: 0.104
# Epoch 33 Loss: 218.921 Accuracy: 0.094 Val_Loss: 223.241 Val_Accuracy: 0.104
# Epoch 34 Loss: 218.451 Accuracy: 0.094 Val_Loss: 222.467 Val_Accuracy: 0.104
# Epoch 35 Loss: 217.707 Accuracy: 0.093 Val_Loss: 224.806 Val_Accuracy: 0.097
# Epoch 36 Loss: 216.700 Accuracy: 0.098 Val_Loss: 224.052 Val_Accuracy: 0.102
# Epoch 37 Loss: 215.795 Accuracy: 0.099 Val_Loss: 223.150 Val_Accuracy: 0.105
# Epoch 38 Loss: 215.052 Accuracy: 0.099 Val_Loss: 223.103 Val_Accuracy: nan
# Epoch 39 Loss: 216.766 Accuracy: 0.096 Val_Loss: 226.233 Val_Accuracy: 0.105
# Epoch 40 Loss: 217.814 Accuracy: 0.096 Val_Loss: 223.437 Val_Accuracy: 0.109
# Epoch 41 Loss: 216.727 Accuracy: 0.098 Val_Loss: 225.916 Val_Accuracy: 0.109
# Epoch 42 Loss: 215.563 Accuracy: nan Val_Loss: 225.502 Val_Accuracy: 0.107
# Epoch 43 Loss: 214.680 Accuracy: 0.102 Val_Loss: 223.714 Val_Accuracy: 0.114
# Epoch 44 Loss: 215.115 Accuracy: 0.101 Val_Loss: 224.614 Val_Accuracy: 0.113
# Epoch 45 Loss: 215.807 Accuracy: nan Val_Loss: 224.899 Val_Accuracy: 0.109
# Epoch 46 Loss: 215.387 Accuracy: 0.104 Val_Loss: 224.850 Val_Accuracy: 0.113
# Epoch 47 Loss: 215.280 Accuracy: 0.106 Val_Loss: 225.026 Val_Accuracy: 0.115
# Epoch 48 Loss: 214.759 Accuracy: 0.106 Val_Loss: 225.175 Val_Accuracy: 0.119
# Epoch 49 Loss: 215.826 Accuracy: 0.109 Val_Loss: 223.157 Val_Accuracy: 0.117
# Epoch 0 Loss: 246.563 Accuracy: 0.055 Val_Loss: 232.098 Val_Accuracy: 0.056
# Epoch 1 Loss: 230.592 Accuracy: 0.057 Val_Loss: 232.880 Val_Accuracy: 0.054
# Epoch 2 Loss: 230.102 Accuracy: 0.055 Val_Loss: 230.893 Val_Accuracy: 0.062
# Epoch 3 Loss: 229.962 Accuracy: 0.058 Val_Loss: 231.877 Val_Accuracy: 0.063
# Epoch 4 Loss: 229.730 Accuracy: 0.064 Val_Loss: 229.522 Val_Accuracy: 0.070
# Epoch 5 Loss: 227.761 Accuracy: 0.070 Val_Loss: 232.007 Val_Accuracy: 0.082
# Epoch 6 Loss: 228.585 Accuracy: 0.070 Val_Loss: 230.298 Val_Accuracy: 0.074
# Epoch 7 Loss: 226.897 Accuracy: 0.075 Val_Loss: 228.647 Val_Accuracy: 0.081
# Epoch 8 Loss: 222.880 Accuracy: 0.073 Val_Loss: 228.108 Val_Accuracy: 0.082
# Epoch 9 Loss: 222.459 Accuracy: 0.071 Val_Loss: 229.196 Val_Accuracy: 0.075
# Epoch 10 Loss: 224.224 Accuracy: 0.071 Val_Loss: 226.952 Val_Accuracy: 0.072
# Epoch 11 Loss: 226.261 Accuracy: 0.076 Val_Loss: 228.822 Val_Accuracy: 0.077
# Epoch 12 Loss: 222.223 Accuracy: 0.074 Val_Loss: 228.107 Val_Accuracy: 0.072
# Epoch 13 Loss: 224.467 Accuracy: 0.077 Val_Loss: 229.282 Val_Accuracy: 0.079
# Epoch 14 Loss: 224.401 Accuracy: 0.075 Val_Loss: 232.413 Val_Accuracy: 0.076
# Epoch 15 Loss: 224.042 Accuracy: 0.076 Val_Loss: 230.372 Val_Accuracy: 0.078
# Epoch 16 Loss: 223.251 Accuracy: 0.077 Val_Loss: 226.926 Val_Accuracy: nan
# Epoch 17 Loss: 222.464 Accuracy: 0.079 Val_Loss: 231.555 Val_Accuracy: 0.090
# Epoch 18 Loss: 223.268 Accuracy: 0.081 Val_Loss: 228.925 Val_Accuracy: 0.096
# Epoch 19 Loss: 223.137 Accuracy: 0.082 Val_Loss: 229.050 Val_Accuracy: 0.093
# Epoch 20 Loss: 220.843 Accuracy: 0.083 Val_Loss: 225.491 Val_Accuracy: 0.104
# Epoch 21 Loss: 220.191 Accuracy: 0.083 Val_Loss: 228.742 Val_Accuracy: 0.096
# Epoch 22 Loss: 221.649 Accuracy: 0.085 Val_Loss: 230.082 Val_Accuracy: 0.085
# Epoch 23 Loss: 220.818 Accuracy: 0.086 Val_Loss: 227.344 Val_Accuracy: 0.094
# Epoch 24 Loss: 219.581 Accuracy: 0.087 Val_Loss: 228.675 Val_Accuracy: 0.099
# Epoch 25 Loss: 221.438 Accuracy: 0.090 Val_Loss: 225.757 Val_Accuracy: 0.099
# Epoch 26 Loss: 220.406 Accuracy: 0.091 Val_Loss: 227.563 Val_Accuracy: 0.102
# Epoch 27 Loss: 218.251 Accuracy: 0.091 Val_Loss: 226.285 Val_Accuracy: 0.096
# Epoch 28 Loss: 218.307 Accuracy: 0.091 Val_Loss: 223.315 Val_Accuracy: 0.100
# Epoch 29 Loss: 216.560 Accuracy: 0.093 Val_Loss: 225.618 Val_Accuracy: nan
# Epoch 30 Loss: 218.775 Accuracy: 0.095 Val_Loss: 228.175 Val_Accuracy: 0.101
# Epoch 31 Loss: 216.455 Accuracy: 0.095 Val_Loss: 224.166 Val_Accuracy: 0.095
# Epoch 32 Loss: 219.552 Accuracy: 0.096 Val_Loss: 227.125 Val_Accuracy: 0.097
# Epoch 33 Loss: 219.004 Accuracy: 0.099 Val_Loss: 223.709 Val_Accuracy: 0.108
# Epoch 34 Loss: 216.189 Accuracy: 0.095 Val_Loss: 226.454 Val_Accuracy: 0.100
# Epoch 35 Loss: 218.555 Accuracy: 0.098 Val_Loss: 225.498 Val_Accuracy: nan
# Epoch 36 Loss: 217.151 Accuracy: 0.100 Val_Loss: 223.891 Val_Accuracy: 0.111
# Epoch 37 Loss: 218.215 Accuracy: 0.097 Val_Loss: 226.614 Val_Accuracy: 0.105
# Epoch 38 Loss: 214.185 Accuracy: 0.105 Val_Loss: 223.975 Val_Accuracy: 0.106
# Epoch 39 Loss: 216.365 Accuracy: 0.103 Val_Loss: 222.063 Val_Accuracy: 0.104
# Epoch 40 Loss: 214.707 Accuracy: 0.102 Val_Loss: 225.029 Val_Accuracy: 0.110
# Epoch 41 Loss: 213.486 Accuracy: 0.104 Val_Loss: 223.981 Val_Accuracy: 0.108
# Epoch 42 Loss: 215.892 Accuracy: 0.103 Val_Loss: 225.191 Val_Accuracy: nan
# Epoch 43 Loss: 216.902 Accuracy: 0.105 Val_Loss: 223.859 Val_Accuracy: 0.110
# Epoch 44 Loss: 215.913 Accuracy: 0.107 Val_Loss: 222.329 Val_Accuracy: 0.110
# Epoch 45 Loss: 215.162 Accuracy: 0.101 Val_Loss: 223.230 Val_Accuracy: 0.106
# Epoch 46 Loss: 215.488 Accuracy: 0.102 Val_Loss: 224.300 Val_Accuracy: 0.111
# Epoch 47 Loss: 213.508 Accuracy: 0.107 Val_Loss: 222.332 Val_Accuracy: 0.115
# Epoch 48 Loss: 216.521 Accuracy: 0.105 Val_Loss: 225.205 Val_Accuracy: 0.111
# Epoch 49 Loss: 216.826 Accuracy: 0.113 Val_Loss: 224.251 Val_Accuracy: 0.109
# Epoch 0 Loss: 247.091 Accuracy: 0.056 Val_Loss: 235.600 Val_Accuracy: 0.054
# Epoch 1 Loss: 229.489 Accuracy: 0.056 Val_Loss: 232.744 Val_Accuracy: 0.051
# Epoch 2 Loss: 231.015 Accuracy: 0.057 Val_Loss: 236.025 Val_Accuracy: 0.067
# Epoch 3 Loss: 229.485 Accuracy: 0.061 Val_Loss: 230.430 Val_Accuracy: 0.064
# Epoch 4 Loss: 225.734 Accuracy: 0.066 Val_Loss: 230.224 Val_Accuracy: 0.075
# Epoch 5 Loss: 225.986 Accuracy: 0.070 Val_Loss: 229.227 Val_Accuracy: nan
# Epoch 6 Loss: 224.005 Accuracy: 0.072 Val_Loss: 230.227 Val_Accuracy: 0.088
# Epoch 7 Loss: 223.693 Accuracy: 0.074 Val_Loss: 227.055 Val_Accuracy: 0.080
# Epoch 8 Loss: 224.350 Accuracy: 0.072 Val_Loss: 229.155 Val_Accuracy: 0.078
# Epoch 9 Loss: 226.020 Accuracy: 0.072 Val_Loss: 228.923 Val_Accuracy: 0.081
# Epoch 10 Loss: 224.250 Accuracy: 0.076 Val_Loss: 226.551 Val_Accuracy: 0.075
# Epoch 11 Loss: 223.592 Accuracy: 0.076 Val_Loss: 229.286 Val_Accuracy: 0.080
# Epoch 12 Loss: 223.323 Accuracy: 0.075 Val_Loss: 230.048 Val_Accuracy: 0.079
# Epoch 13 Loss: 225.864 Accuracy: 0.077 Val_Loss: 230.057 Val_Accuracy: 0.082
# Epoch 14 Loss: 223.417 Accuracy: 0.080 Val_Loss: 228.604 Val_Accuracy: 0.073
# Epoch 15 Loss: 222.872 Accuracy: 0.078 Val_Loss: 231.924 Val_Accuracy: 0.080
# Epoch 16 Loss: 221.842 Accuracy: 0.082 Val_Loss: 232.728 Val_Accuracy: 0.089
# Epoch 17 Loss: 224.193 Accuracy: 0.081 Val_Loss: 227.441 Val_Accuracy: 0.089
# Epoch 18 Loss: 222.205 Accuracy: 0.083 Val_Loss: 228.902 Val_Accuracy: 0.087
# Epoch 19 Loss: 219.817 Accuracy: 0.080 Val_Loss: 227.097 Val_Accuracy: 0.093
# Epoch 20 Loss: 221.114 Accuracy: 0.084 Val_Loss: 229.619 Val_Accuracy: 0.087
# Epoch 21 Loss: 222.360 Accuracy: 0.082 Val_Loss: 225.681 Val_Accuracy: 0.096
# Epoch 22 Loss: 219.199 Accuracy: 0.087 Val_Loss: 228.864 Val_Accuracy: 0.098
# Epoch 23 Loss: 219.215 Accuracy: 0.085 Val_Loss: 224.818 Val_Accuracy: 0.101
# Epoch 24 Loss: 221.458 Accuracy: 0.087 Val_Loss: 229.576 Val_Accuracy: 0.100
# Epoch 25 Loss: 219.247 Accuracy: 0.086 Val_Loss: 227.203 Val_Accuracy: 0.103
# Epoch 26 Loss: 218.700 Accuracy: 0.093 Val_Loss: 225.946 Val_Accuracy: 0.092
# Epoch 27 Loss: 221.025 Accuracy: 0.095 Val_Loss: 224.316 Val_Accuracy: 0.103
# Epoch 28 Loss: 216.425 Accuracy: 0.093 Val_Loss: 224.449 Val_Accuracy: 0.100
# Epoch 29 Loss: 217.733 Accuracy: 0.093 Val_Loss: 227.717 Val_Accuracy: 0.095
# Epoch 30 Loss: 217.116 Accuracy: 0.093 Val_Loss: 224.911 Val_Accuracy: 0.100
# Epoch 31 Loss: 218.797 Accuracy: 0.096 Val_Loss: 225.742 Val_Accuracy: 0.100
# Epoch 32 Loss: 217.552 Accuracy: 0.096 Val_Loss: 227.909 Val_Accuracy: 0.102
# Epoch 33 Loss: 218.515 Accuracy: 0.096 Val_Loss: 224.821 Val_Accuracy: 0.105
# Epoch 34 Loss: 219.181 Accuracy: 0.098 Val_Loss: 229.326 Val_Accuracy: 0.104
# Epoch 35 Loss: 218.402 Accuracy: 0.099 Val_Loss: 227.351 Val_Accuracy: 0.103
# Epoch 36 Loss: 216.449 Accuracy: 0.102 Val_Loss: 224.039 Val_Accuracy: 0.109
# Epoch 37 Loss: 217.646 Accuracy: 0.102 Val_Loss: 225.784 Val_Accuracy: 0.108
# Epoch 38 Loss: 215.390 Accuracy: 0.102 Val_Loss: 227.797 Val_Accuracy: 0.105
# Epoch 39 Loss: 216.622 Accuracy: 0.103 Val_Loss: 228.391 Val_Accuracy: 0.109
# Epoch 40 Loss: 214.364 Accuracy: 0.107 Val_Loss: 226.395 Val_Accuracy: 0.112
# Epoch 41 Loss: 216.420 Accuracy: 0.103 Val_Loss: 227.669 Val_Accuracy: 0.104
# Epoch 42 Loss: 216.516 Accuracy: 0.107 Val_Loss: 227.490 Val_Accuracy: nan
# Epoch 43 Loss: 215.113 Accuracy: 0.114 Val_Loss: 224.161 Val_Accuracy: 0.112
# Epoch 44 Loss: 214.971 Accuracy: 0.108 Val_Loss: 223.286 Val_Accuracy: 0.114
# Epoch 45 Loss: 214.791 Accuracy: 0.108 Val_Loss: 225.397 Val_Accuracy: 0.107
# Epoch 46 Loss: 216.512 Accuracy: 0.113 Val_Loss: 226.120 Val_Accuracy: 0.111
# Epoch 47 Loss: 214.238 Accuracy: 0.111 Val_Loss: 225.953 Val_Accuracy: 0.115
# Epoch 48 Loss: 214.945 Accuracy: 0.113 Val_Loss: 225.102 Val_Accuracy: 0.115
# Epoch 49 Loss: 214.338 Accuracy: nan Val_Loss: 222.928 Val_Accuracy: 0.117
# Epoch 0 Loss: 239.519 Accuracy: 0.053 Val_Loss: 235.398 Val_Accuracy: 0.054
# Epoch 1 Loss: 230.262 Accuracy: 0.053 Val_Loss: 234.177 Val_Accuracy: 0.063
# Epoch 2 Loss: 231.170 Accuracy: 0.061 Val_Loss: 232.114 Val_Accuracy: 0.071
# Epoch 3 Loss: 228.295 Accuracy: 0.065 Val_Loss: 235.982 Val_Accuracy: 0.054
# Epoch 4 Loss: 225.931 Accuracy: 0.068 Val_Loss: 232.040 Val_Accuracy: 0.065
# Epoch 5 Loss: 227.755 Accuracy: 0.071 Val_Loss: 229.503 Val_Accuracy: nan
# Epoch 6 Loss: 225.057 Accuracy: 0.070 Val_Loss: 229.231 Val_Accuracy: 0.072
# Epoch 7 Loss: 225.589 Accuracy: 0.074 Val_Loss: 228.948 Val_Accuracy: 0.072
# Epoch 8 Loss: 227.130 Accuracy: 0.075 Val_Loss: 232.129 Val_Accuracy: nan
# Epoch 9 Loss: 222.648 Accuracy: 0.076 Val_Loss: 229.828 Val_Accuracy: 0.075
# Epoch 10 Loss: 223.006 Accuracy: 0.075 Val_Loss: 232.340 Val_Accuracy: 0.079
# Epoch 11 Loss: 222.535 Accuracy: 0.074 Val_Loss: 227.953 Val_Accuracy: 0.089
# Epoch 12 Loss: 225.428 Accuracy: 0.077 Val_Loss: 228.146 Val_Accuracy: 0.078
# Epoch 13 Loss: 221.616 Accuracy: 0.080 Val_Loss: 229.055 Val_Accuracy: 0.082
# Epoch 14 Loss: 225.434 Accuracy: 0.081 Val_Loss: 226.604 Val_Accuracy: 0.095
# Epoch 15 Loss: 223.565 Accuracy: 0.081 Val_Loss: 227.419 Val_Accuracy: 0.088
# Epoch 16 Loss: 223.783 Accuracy: 0.085 Val_Loss: 230.303 Val_Accuracy: 0.087
# Epoch 17 Loss: 222.952 Accuracy: 0.082 Val_Loss: 228.422 Val_Accuracy: 0.092
# Epoch 18 Loss: 220.771 Accuracy: 0.087 Val_Loss: 230.383 Val_Accuracy: 0.097
# Epoch 19 Loss: 220.735 Accuracy: 0.087 Val_Loss: 226.533 Val_Accuracy: 0.090
# Epoch 20 Loss: 220.577 Accuracy: 0.090 Val_Loss: 227.245 Val_Accuracy: 0.101
# Epoch 21 Loss: 221.709 Accuracy: 0.089 Val_Loss: 228.192 Val_Accuracy: 0.096
# Epoch 22 Loss: 218.368 Accuracy: 0.091 Val_Loss: 229.611 Val_Accuracy: 0.104
# Epoch 23 Loss: 219.858 Accuracy: 0.094 Val_Loss: 223.422 Val_Accuracy: 0.104
# Epoch 24 Loss: 218.605 Accuracy: 0.094 Val_Loss: 226.079 Val_Accuracy: 0.104
# Epoch 25 Loss: 218.485 Accuracy: 0.094 Val_Loss: 228.823 Val_Accuracy: 0.095
# ...
# Epoch 42 Loss: 213.975 Accuracy: 0.117 Val_Loss: 226.090 Val_Accuracy: 0.126
# Epoch 43 Loss: 212.245 Accuracy: 0.116 Val_Loss: 226.363 Val_Accuracy: 0.120
# Epoch 44 Loss: 214.215 Accuracy: 0.117 Val_Loss: 229.381 Val_Accuracy: 0.114
# Epoch 45 Loss: 214.346 Accuracy: 0.116 Val_Loss: 225.092 Val_Accuracy: 0.115
# Epoch 46 Loss: 211.883 Accuracy: 0.116 Val_Loss: 226.521 Val_Accuracy: 0.117
# Epoch 47 Loss: 211.545 Accuracy: 0.117 Val_Loss: 226.613 Val_Accuracy: 0.119
# Epoch 48 Loss: 214.556 Accuracy: 0.119 Val_Loss: 224.996 Val_Accuracy: 0.121
# Epoch 49 Loss: 214.872 Accuracy: 0.119 Val_Loss: 228.230 Val_Accuracy: 0.121
# Epoch 0 Loss: 239.133 Accuracy: 0.053 Val_Loss: 236.141 Val_Accuracy: 0.059
# Epoch 1 Loss: 232.714 Accuracy: 0.057 Val_Loss: 235.726 Val_Accuracy: nan
# Epoch 2 Loss: 229.770 Accuracy: 0.060 Val_Loss: 233.665 Val_Accuracy: 0.055
# Epoch 3 Loss: 228.450 Accuracy: 0.068 Val_Loss: 230.766 Val_Accuracy: 0.069
# Epoch 4 Loss: 226.391 Accuracy: 0.071 Val_Loss: 232.322 Val_Accuracy: 0.075
# Epoch 5 Loss: 227.769 Accuracy: 0.070 Val_Loss: 228.340 Val_Accuracy: 0.079
# Epoch 6 Loss: 226.325 Accuracy: 0.074 Val_Loss: 229.571 Val_Accuracy: 0.074
# Epoch 7 Loss: 223.594 Accuracy: 0.079 Val_Loss: 228.231 Val_Accuracy: 0.092
# Epoch 8 Loss: 227.251 Accuracy: 0.083 Val_Loss: 226.567 Val_Accuracy: 0.091
# Epoch 9 Loss: 221.623 Accuracy: 0.086 Val_Loss: 229.746 Val_Accuracy: 0.083
# Epoch 10 Loss: 220.839 Accuracy: 0.085 Val_Loss: 229.797 Val_Accuracy: 0.091
# Epoch 11 Loss: 220.534 Accuracy: 0.089 Val_Loss: 228.966 Val_Accuracy: 0.093
# Epoch 12 Loss: 221.931 Accuracy: 0.092 Val_Loss: 230.269 Val_Accuracy: 0.093
# Epoch 13 Loss: 222.021 Accuracy: 0.091 Val_Loss: 229.275 Val_Accuracy: nan
# Epoch 14 Loss: 219.418 Accuracy: 0.094 Val_Loss: 229.245 Val_Accuracy: 0.105
# Epoch 15 Loss: 220.629 Accuracy: 0.094 Val_Loss: 226.461 Val_Accuracy: 0.104
# Epoch 16 Loss: 220.048 Accuracy: 0.098 Val_Loss: 233.764 Val_Accuracy: 0.104
# Epoch 17 Loss: 217.883 Accuracy: 0.099 Val_Loss: 230.456 Val_Accuracy: nan
# Epoch 18 Loss: 218.250 Accuracy: 0.100 Val_Loss: 225.675 Val_Accuracy: 0.112
# Epoch 19 Loss: 217.758 Accuracy: 0.101 Val_Loss: 223.553 Val_Accuracy: 0.109
# Epoch 20 Loss: 218.980 Accuracy: 0.103 Val_Loss: 230.073 Val_Accuracy: 0.107
# Epoch 21 Loss: 215.544 Accuracy: 0.104 Val_Loss: 235.441 Val_Accuracy: 0.111
# Epoch 22 Loss: 215.985 Accuracy: nan Val_Loss: 226.592 Val_Accuracy: 0.111
# Epoch 23 Loss: 217.716 Accuracy: 0.108 Val_Loss: 225.445 Val_Accuracy: 0.114
# Epoch 24 Loss: 217.544 Accuracy: 0.110 Val_Loss: 225.610 Val_Accuracy: 0.110
# Epoch 25 Loss: 217.373 Accuracy: 0.109 Val_Loss: 226.077 Val_Accuracy: 0.114
# Epoch 26 Loss: 216.603 Accuracy: 0.113 Val_Loss: 229.840 Val_Accuracy: 0.110
# Epoch 27 Loss: 213.929 Accuracy: 0.116 Val_Loss: 224.479 Val_Accuracy: 0.113
# Epoch 28 Loss: 215.369 Accuracy: 0.114 Val_Loss: 226.194 Val_Accuracy: nan
# Epoch 29 Loss: 213.880 Accuracy: 0.113 Val_Loss: 226.563 Val_Accuracy: 0.119
# Epoch 30 Loss: 213.697 Accuracy: 0.111 Val_Loss: 229.143 Val_Accuracy: 0.115
# Epoch 31 Loss: 215.189 Accuracy: 0.112 Val_Loss: 224.266 Val_Accuracy: 0.127
# Epoch 32 Loss: 215.639 Accuracy: 0.115 Val_Loss: 227.073 Val_Accuracy: 0.116
# Epoch 33 Loss: 214.093 Accuracy: 0.116 Val_Loss: 224.997 Val_Accuracy: 0.118
# Epoch 34 Loss: 214.594 Accuracy: 0.118 Val_Loss: 227.264 Val_Accuracy: 0.115
# Epoch 35 Loss: 213.609 Accuracy: 0.119 Val_Loss: 226.551 Val_Accuracy: 0.120
# Epoch 36 Loss: 215.697 Accuracy: 0.115 Val_Loss: 230.492 Val_Accuracy: 0.118
# Epoch 37 Loss: 213.544 Accuracy: 0.123 Val_Loss: 226.322 Val_Accuracy: 0.119
# Epoch 38 Loss: 214.794 Accuracy: 0.118 Val_Loss: 235.937 Val_Accuracy: 0.121
# Epoch 39 Loss: 214.128 Accuracy: 0.120 Val_Loss: 227.321 Val_Accuracy: 0.122
# Epoch 40 Loss: 214.210 Accuracy: 0.122 Val_Loss: 224.946 Val_Accuracy: 0.125
# Epoch 41 Loss: 214.381 Accuracy: 0.119 Val_Loss: 225.959 Val_Accuracy: 0.124
# Epoch 42 Loss: 213.739 Accuracy: nan Val_Loss: 221.900 Val_Accuracy: 0.126
# Epoch 43 Loss: 213.619 Accuracy: 0.118 Val_Loss: 224.643 Val_Accuracy: 0.123
# Epoch 44 Loss: 214.718 Accuracy: 0.119 Val_Loss: 225.054 Val_Accuracy: 0.120
# Epoch 45 Loss: 215.350 Accuracy: 0.119 Val_Loss: 224.468 Val_Accuracy: 0.122
# Epoch 46 Loss: 213.200 Accuracy: 0.122 Val_Loss: 221.720 Val_Accuracy: 0.133
# Epoch 47 Loss: 214.167 Accuracy: 0.120 Val_Loss: 226.963 Val_Accuracy: 0.122
# Epoch 48 Loss: 214.707 Accuracy: 0.123 Val_Loss: 226.406 Val_Accuracy: 0.116
# Epoch 49 Loss: 211.908 Accuracy: nan Val_Loss: 224.877 Val_Accuracy: 0.118
# Epoch 0 Loss: 240.232 Accuracy: 0.055 Val_Loss: 235.210 Val_Accuracy: 0.053
# Epoch 1 Loss: 230.415 Accuracy: 0.055 Val_Loss: 235.755 Val_Accuracy: 0.067
# Epoch 2 Loss: 230.316 Accuracy: 0.063 Val_Loss: 232.821 Val_Accuracy: nan
# Epoch 3 Loss: 228.993 Accuracy: 0.067 Val_Loss: 228.944 Val_Accuracy: 0.079
# Epoch 4 Loss: 228.733 Accuracy: nan Val_Loss: 233.290 Val_Accuracy: 0.071
# Epoch 5 Loss: 225.587 Accuracy: 0.072 Val_Loss: 228.987 Val_Accuracy: 0.074
# Epoch 6 Loss: 225.109 Accuracy: 0.075 Val_Loss: 230.077 Val_Accuracy: 0.095
# Epoch 7 Loss: 226.105 Accuracy: 0.080 Val_Loss: 236.250 Val_Accuracy: 0.080
# Epoch 8 Loss: 225.337 Accuracy: 0.081 Val_Loss: 229.205 Val_Accuracy: 0.094
# Epoch 9 Loss: 222.717 Accuracy: 0.086 Val_Loss: 228.488 Val_Accuracy: 0.098
# Epoch 10 Loss: 223.028 Accuracy: 0.084 Val_Loss: 236.433 Val_Accuracy: 0.094
# Epoch 11 Loss: 221.847 Accuracy: nan Val_Loss: 227.218 Val_Accuracy: 0.100
# Epoch 12 Loss: 219.823 Accuracy: 0.090 Val_Loss: 233.262 Val_Accuracy: 0.093
# Epoch 13 Loss: 222.718 Accuracy: 0.093 Val_Loss: 228.410 Val_Accuracy: 0.100
# Epoch 14 Loss: 220.089 Accuracy: 0.092 Val_Loss: 229.806 Val_Accuracy: 0.100
# Epoch 15 Loss: 223.427 Accuracy: 0.094 Val_Loss: 228.317 Val_Accuracy: 0.100
# Epoch 16 Loss: 218.706 Accuracy: 0.098 Val_Loss: 226.179 Val_Accuracy: nan
# Epoch 17 Loss: 219.380 Accuracy: nan Val_Loss: 227.311 Val_Accuracy: 0.106
# Epoch 18 Loss: 218.479 Accuracy: 0.101 Val_Loss: 230.251 Val_Accuracy: nan
# Epoch 19 Loss: 218.950 Accuracy: 0.100 Val_Loss: 226.897 Val_Accuracy: 0.102
# Epoch 20 Loss: 218.499 Accuracy: 0.103 Val_Loss: 232.658 Val_Accuracy: 0.111
# Epoch 21 Loss: 217.376 Accuracy: 0.105 Val_Loss: 227.496 Val_Accuracy: 0.110
# Epoch 22 Loss: 217.619 Accuracy: 0.105 Val_Loss: 226.598 Val_Accuracy: 0.109
# Epoch 23 Loss: 217.895 Accuracy: 0.108 Val_Loss: 228.187 Val_Accuracy: 0.110
# Epoch 24 Loss: 216.173 Accuracy: 0.115 Val_Loss: 224.438 Val_Accuracy: 0.113
# Epoch 25 Loss: 216.279 Accuracy: 0.108 Val_Loss: 229.719 Val_Accuracy: 0.119
# Epoch 26 Loss: 215.950 Accuracy: 0.110 Val_Loss: 227.833 Val_Accuracy: 0.112
# Epoch 27 Loss: 217.390 Accuracy: 0.106 Val_Loss: 229.241 Val_Accuracy: 0.108
# Epoch 28 Loss: 216.999 Accuracy: 0.114 Val_Loss: 226.587 Val_Accuracy: 0.114
# Epoch 29 Loss: 216.189 Accuracy: 0.110 Val_Loss: 226.702 Val_Accuracy: 0.111
# Epoch 30 Loss: 214.357 Accuracy: 0.115 Val_Loss: 228.084 Val_Accuracy: 0.112
# Epoch 31 Loss: 216.287 Accuracy: 0.111 Val_Loss: 225.647 Val_Accuracy: 0.110
# Epoch 32 Loss: 215.737 Accuracy: 0.111 Val_Loss: 227.660 Val_Accuracy: 0.117
# Epoch 33 Loss: 213.836 Accuracy: 0.114 Val_Loss: 228.791 Val_Accuracy: 0.112
# Epoch 34 Loss: 216.575 Accuracy: 0.115 Val_Loss: 224.907 Val_Accuracy: 0.113
# Epoch 35 Loss: 213.521 Accuracy: 0.117 Val_Loss: 225.084 Val_Accuracy: 0.118
# Epoch 36 Loss: 214.405 Accuracy: 0.111 Val_Loss: 224.156 Val_Accuracy: 0.112
# Epoch 37 Loss: 214.410 Accuracy: 0.113 Val_Loss: 225.168 Val_Accuracy: 0.112
# Epoch 38 Loss: 215.528 Accuracy: 0.115 Val_Loss: 225.869 Val_Accuracy: 0.120
# Epoch 39 Loss: 215.093 Accuracy: 0.122 Val_Loss: 224.618 Val_Accuracy: 0.121
# Epoch 40 Loss: 214.781 Accuracy: 0.116 Val_Loss: 229.301 Val_Accuracy: 0.120
# Epoch 41 Loss: 213.263 Accuracy: 0.117 Val_Loss: 225.142 Val_Accuracy: 0.123
# Epoch 42 Loss: 213.851 Accuracy: 0.117 Val_Loss: 225.092 Val_Accuracy: 0.128
# Epoch 43 Loss: 214.997 Accuracy: 0.120 Val_Loss: 225.482 Val_Accuracy: 0.121
# Epoch 44 Loss: 213.965 Accuracy: 0.119 Val_Loss: 223.849 Val_Accuracy: 0.125
# Epoch 45 Loss: 214.158 Accuracy: 0.122 Val_Loss: 225.241 Val_Accuracy: 0.125
# Epoch 46 Loss: 214.027 Accuracy: 0.120 Val_Loss: 221.941 Val_Accuracy: 0.120
# Epoch 47 Loss: 214.356 Accuracy: 0.118 Val_Loss: 227.087 Val_Accuracy: 0.118
# Epoch 48 Loss: 213.301 Accuracy: 0.120 Val_Loss: 226.172 Val_Accuracy: 0.118
# Epoch 49 Loss: 212.152 Accuracy: 0.120 Val_Loss: 224.677 Val_Accuracy: 0.125
# Epoch 0 Loss: 238.988 Accuracy: 0.054 Val_Loss: 235.830 Val_Accuracy: 0.059
# Epoch 1 Loss: 232.009 Accuracy: nan Val_Loss: 233.938 Val_Accuracy: 0.078
# Epoch 2 Loss: 232.213 Accuracy: 0.059 Val_Loss: 237.609 Val_Accuracy: 0.077
# Epoch 3 Loss: 226.258 Accuracy: 0.067 Val_Loss: 231.149 Val_Accuracy: 0.075
# Epoch 4 Loss: 227.120 Accuracy: 0.074 Val_Loss: 230.891 Val_Accuracy: nan
# Epoch 5 Loss: 225.587 Accuracy: 0.073 Val_Loss: 226.750 Val_Accuracy: 0.081
# Epoch 6 Loss: 224.695 Accuracy: 0.073 Val_Loss: 226.363 Val_Accuracy: 0.084
# Epoch 7 Loss: 223.672 Accuracy: 0.076 Val_Loss: 226.637 Val_Accuracy: 0.089
# Epoch 8 Loss: 222.728 Accuracy: 0.084 Val_Loss: 230.617 Val_Accuracy: 0.091
# Epoch 9 Loss: 220.856 Accuracy: 0.081 Val_Loss: 225.828 Val_Accuracy: 0.100
# Epoch 10 Loss: 221.833 Accuracy: 0.085 Val_Loss: 226.398 Val_Accuracy: 0.087
# Epoch 11 Loss: 222.367 Accuracy: 0.089 Val_Loss: 228.315 Val_Accuracy: 0.096
# Epoch 12 Loss: 221.091 Accuracy: 0.090 Val_Loss: 228.274 Val_Accuracy: 0.101
# Epoch 13 Loss: 221.016 Accuracy: 0.088 Val_Loss: 226.778 Val_Accuracy: 0.101
# Epoch 14 Loss: 221.667 Accuracy: 0.089 Val_Loss: 227.835 Val_Accuracy: 0.102
# Epoch 15 Loss: 220.742 Accuracy: 0.093 Val_Loss: 228.358 Val_Accuracy: 0.098
# Epoch 16 Loss: 219.221 Accuracy: 0.092 Val_Loss: 233.681 Val_Accuracy: 0.099
# Epoch 17 Loss: 217.552 Accuracy: 0.093 Val_Loss: 228.783 Val_Accuracy: nan
# Epoch 18 Loss: 219.638 Accuracy: 0.093 Val_Loss: 226.502 Val_Accuracy: 0.100
# Epoch 19 Loss: 219.824 Accuracy: 0.096 Val_Loss: 224.602 Val_Accuracy: 0.105
# Epoch 20 Loss: 220.083 Accuracy: 0.095 Val_Loss: 230.251 Val_Accuracy: 0.105
# Epoch 21 Loss: 219.768 Accuracy: 0.095 Val_Loss: 229.411 Val_Accuracy: 0.102
# Epoch 22 Loss: 217.088 Accuracy: 0.097 Val_Loss: 227.462 Val_Accuracy: 0.113
# Epoch 23 Loss: 216.197 Accuracy: 0.098 Val_Loss: 224.903 Val_Accuracy: 0.106
# Epoch 24 Loss: 218.228 Accuracy: 0.100 Val_Loss: 228.114 Val_Accuracy: 0.111
# Epoch 25 Loss: 217.056 Accuracy: 0.097 Val_Loss: 226.261 Val_Accuracy: 0.107
# Epoch 26 Loss: 218.107 Accuracy: 0.103 Val_Loss: 228.605 Val_Accuracy: 0.108
# Epoch 27 Loss: 217.412 Accuracy: 0.105 Val_Loss: 227.238 Val_Accuracy: 0.104
# Epoch 28 Loss: 216.330 Accuracy: 0.108 Val_Loss: 225.605 Val_Accuracy: 0.111
# Epoch 29 Loss: 219.304 Accuracy: 0.104 Val_Loss: 224.091 Val_Accuracy: 0.119
# Epoch 30 Loss: 218.431 Accuracy: 0.105 Val_Loss: 226.632 Val_Accuracy: 0.112
# Epoch 31 Loss: 216.166 Accuracy: 0.106 Val_Loss: 227.071 Val_Accuracy: 0.115
# Epoch 32 Loss: 215.514 Accuracy: 0.109 Val_Loss: 230.461 Val_Accuracy: 0.114
# Epoch 33 Loss: 215.003 Accuracy: 0.112 Val_Loss: 227.590 Val_Accuracy: 0.118
# Epoch 34 Loss: 215.871 Accuracy: 0.111 Val_Loss: 228.711 Val_Accuracy: 0.119
# Epoch 35 Loss: 216.103 Accuracy: 0.110 Val_Loss: 225.587 Val_Accuracy: 0.120
# Epoch 36 Loss: 214.674 Accuracy: 0.114 Val_Loss: 228.096 Val_Accuracy: 0.112
# Epoch 37 Loss: 215.020 Accuracy: 0.109 Val_Loss: 224.350 Val_Accuracy: 0.119
# Epoch 38 Loss: 215.394 Accuracy: 0.110 Val_Loss: 223.392 Val_Accuracy: 0.117
# Epoch 39 Loss: 215.137 Accuracy: 0.118 Val_Loss: 226.859 Val_Accuracy: 0.116
# Epoch 40 Loss: 214.667 Accuracy: 0.113 Val_Loss: 226.896 Val_Accuracy: 0.117
# Epoch 41 Loss: 212.063 Accuracy: 0.113 Val_Loss: 227.365 Val_Accuracy: nan
# Epoch 42 Loss: 214.879 Accuracy: 0.113 Val_Loss: 225.215 Val_Accuracy: 0.114
# Epoch 43 Loss: 213.104 Accuracy: 0.115 Val_Loss: 229.084 Val_Accuracy: 0.124
# Epoch 44 Loss: 214.186 Accuracy: 0.115 Val_Loss: 227.720 Val_Accuracy: 0.112
# Epoch 45 Loss: 214.062 Accuracy: 0.119 Val_Loss: 225.953 Val_Accuracy: 0.124
# Epoch 46 Loss: 212.810 Accuracy: 0.119 Val_Loss: 226.857 Val_Accuracy: 0.117
# Epoch 47 Loss: 214.284 Accuracy: 0.115 Val_Loss: 225.609 Val_Accuracy: 0.123
# Epoch 48 Loss: 212.814 Accuracy: 0.119 Val_Loss: 226.707 Val_Accuracy: nan
# Epoch 49 Loss: 212.267 Accuracy: 0.124 Val_Loss: 223.360 Val_Accuracy: 0.124
# Epoch 0 Loss: 239.563 Accuracy: 0.054 Val_Loss: 236.279 Val_Accuracy: 0.056
# Epoch 1 Loss: 232.104 Accuracy: 0.055 Val_Loss: 235.604 Val_Accuracy: 0.058
# Epoch 2 Loss: 231.268 Accuracy: 0.059 Val_Loss: 232.427 Val_Accuracy: 0.069
# Epoch 3 Loss: 227.075 Accuracy: 0.067 Val_Loss: 232.890 Val_Accuracy: 0.072
# Epoch 4 Loss: 226.860 Accuracy: 0.070 Val_Loss: 231.645 Val_Accuracy: 0.081
# Epoch 5 Loss: 223.961 Accuracy: 0.075 Val_Loss: 229.158 Val_Accuracy: 0.084
# Epoch 6 Loss: 228.225 Accuracy: 0.074 Val_Loss: 234.426 Val_Accuracy: 0.089
# Epoch 7 Loss: 223.400 Accuracy: 0.079 Val_Loss: 229.496 Val_Accuracy: 0.086
# Epoch 8 Loss: 221.738 Accuracy: 0.076 Val_Loss: 229.770 Val_Accuracy: 0.087
# Epoch 9 Loss: 220.617 Accuracy: 0.083 Val_Loss: 229.936 Val_Accuracy: 0.094
# Epoch 10 Loss: 221.751 Accuracy: 0.081 Val_Loss: 224.375 Val_Accuracy: 0.094
# Epoch 11 Loss: 219.305 Accuracy: 0.089 Val_Loss: 228.371 Val_Accuracy: 0.092
# Epoch 12 Loss: 219.831 Accuracy: 0.088 Val_Loss: 229.129 Val_Accuracy: 0.094
# Epoch 13 Loss: 221.714 Accuracy: 0.089 Val_Loss: 229.228 Val_Accuracy: 0.100
# Epoch 14 Loss: 220.646 Accuracy: 0.091 Val_Loss: 230.185 Val_Accuracy: nan
# Epoch 15 Loss: 219.193 Accuracy: 0.089 Val_Loss: 229.257 Val_Accuracy: 0.099
# Epoch 16 Loss: 217.719 Accuracy: 0.091 Val_Loss: 227.533 Val_Accuracy: 0.100
# Epoch 17 Loss: 218.357 Accuracy: 0.094 Val_Loss: 227.103 Val_Accuracy: 0.096
# Epoch 18 Loss: 220.978 Accuracy: 0.095 Val_Loss: 225.473 Val_Accuracy: 0.104
# Epoch 19 Loss: 218.916 Accuracy: 0.095 Val_Loss: 227.312 Val_Accuracy: 0.109
# Epoch 20 Loss: 217.341 Accuracy: 0.097 Val_Loss: 224.830 Val_Accuracy: 0.112
# Epoch 21 Loss: 217.841 Accuracy: 0.095 Val_Loss: 230.970 Val_Accuracy: 0.108
# Epoch 22 Loss: 215.916 Accuracy: 0.100 Val_Loss: 228.985 Val_Accuracy: 0.108
# Epoch 23 Loss: 219.504 Accuracy: 0.098 Val_Loss: 228.899 Val_Accuracy: 0.105
# Epoch 24 Loss: 218.245 Accuracy: 0.099 Val_Loss: 228.520 Val_Accuracy: 0.101
# Epoch 25 Loss: 218.571 Accuracy: 0.098 Val_Loss: 229.778 Val_Accuracy: 0.107
# Epoch 26 Loss: 217.690 Accuracy: 0.101 Val_Loss: 227.672 Val_Accuracy: 0.112
# Epoch 27 Loss: 215.005 Accuracy: 0.102 Val_Loss: 229.250 Val_Accuracy: 0.108
# Epoch 28 Loss: 217.125 Accuracy: 0.102 Val_Loss: 229.645 Val_Accuracy: 0.110
# Epoch 29 Loss: 216.608 Accuracy: 0.099 Val_Loss: 227.891 Val_Accuracy: 0.106
# Epoch 30 Loss: 216.634 Accuracy: 0.103 Val_Loss: 228.559 Val_Accuracy: 0.109
# Epoch 31 Loss: 215.754 Accuracy: 0.105 Val_Loss: 230.698 Val_Accuracy: 0.101
# Epoch 32 Loss: 213.829 Accuracy: nan Val_Loss: 228.180 Val_Accuracy: 0.113
# Epoch 33 Loss: 215.216 Accuracy: 0.106 Val_Loss: 227.790 Val_Accuracy: nan
# Epoch 34 Loss: 216.127 Accuracy: 0.106 Val_Loss: 226.447 Val_Accuracy: 0.111
# Epoch 35 Loss: 215.607 Accuracy: 0.108 Val_Loss: 225.512 Val_Accuracy: 0.110
# Epoch 36 Loss: 215.691 Accuracy: 0.106 Val_Loss: 230.044 Val_Accuracy: 0.100
# Epoch 37 Loss: 214.738 Accuracy: 0.106 Val_Loss: 231.472 Val_Accuracy: 0.105
# Epoch 38 Loss: 216.109 Accuracy: nan Val_Loss: 229.040 Val_Accuracy: 0.110
# Epoch 39 Loss: 214.348 Accuracy: 0.107 Val_Loss: 229.562 Val_Accuracy: 0.116
# Epoch 40 Loss: 216.758 Accuracy: 0.107 Val_Loss: 229.617 Val_Accuracy: 0.103
# Epoch 41 Loss: 213.688 Accuracy: 0.109 Val_Loss: 227.188 Val_Accuracy: 0.116
# Epoch 42 Loss: 213.234 Accuracy: 0.107 Val_Loss: 222.634 Val_Accuracy: 0.120
# Epoch 43 Loss: 216.244 Accuracy: 0.115 Val_Loss: 228.910 Val_Accuracy: 0.118
# Epoch 44 Loss: 215.648 Accuracy: 0.111 Val_Loss: 226.953 Val_Accuracy: 0.112
# Epoch 45 Loss: 214.630 Accuracy: 0.110 Val_Loss: 225.946 Val_Accuracy: nan
# Epoch 46 Loss: 214.051 Accuracy: 0.113 Val_Loss: 227.092 Val_Accuracy: 0.113
# Epoch 47 Loss: 214.310 Accuracy: 0.110 Val_Loss: 226.805 Val_Accuracy: 0.117
# Epoch 48 Loss: 213.661 Accuracy: 0.112 Val_Loss: 231.141 Val_Accuracy: 0.113
# Epoch 49 Loss: 212.320 Accuracy: 0.112 Val_Loss: 227.816 Val_Accuracy: 0.115

# %% [markdown]
# #### Plot the performance

# %%
perf_file = open('performance_1l.pkl', 'rb')
performance = pickle.load(perf_file)
perf_file.close()

keys = list(performance.keys())
n_keys = len(keys)
c = np.random.rand(n_keys) * 3
norm = matplotlib.colors.Normalize(vmin=0, vmax=3)
cmap = plt.cm.rainbow

import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(10, 15))
axes[0].set_title('Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('CrossEntropy')
axes[1].set_title('Accuracy')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
# axes[0].plot(range(len(train_loss_results)), train_loss_results, '-r', label='training')

for key, i in zip(keys, range(n_keys)):
    tmp_loss_acc = performance[key]
    axes[0].plot(range(EPOCHS), tmp_loss_acc[:, 0], c=cmap(norm(c[i])), label=key)
    axes[1].plot(range(EPOCHS), tmp_loss_acc[:, 1], c=cmap(norm(c[i])), label=key)

axes[0].grid(True)
# axes[0].legend()
axes[1].grid(True)
# axes[1].legend()
# axes[1].plot(range(len(train_accuracy_results)), train_accuracy_results, '-r', label='training')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Moving average
# for key in  keys:
#     if (performance[key][:, 0] == np.nan).any() or (performance[key][:, 1] == np.nan).any():
#         print('nan found')
print(performance['128,4,0.15'][:, -1])
print(performance['128,4,0.15'][:, -1][2])
print(type(performance['128,4,0.15'][:, -1][2]))
any([math.isnan(e) for e in performance['128,4,0.15'][:, -1]])
# Out:
# [0.05450804 0.05023003        nan 0.06703164 0.07115673 0.07462306
#  0.06734305 0.07148367 0.07062805 0.07736326 0.07495247 0.07420566
#  0.08355295 0.07579081 0.0793337  0.08671837 0.08895482 0.09128039
#  0.08546905 0.08844045 0.0947853  0.08530635 0.09331235 0.09881746
#  0.08861834 0.0896976  0.10228613 0.09431574 0.10484477 0.09653278
#  0.09739635        nan 0.10056282 0.09750094 0.10021588 0.10182509
#  0.10233739 0.1021123  0.1084828         nan 0.10244526 0.10589474
#  0.10546809 0.10965379 0.10780047 0.10513072 0.1098827  0.1099591
#         nan 0.11084422]
# nan
# <class 'numpy.float32'>
# True

# %% [markdown]
# #### Nothing is easily traceable at this point, so we shall do a moving average to smoothen the plot

# %%
def filterout_nans(x):
    b_indices = [math.isnan(e) is False for e in x]
    return x[b_indices]

perf_file = open('performance_1l.pkl', 'rb')
performance = pickle.load(perf_file)
perf_file.close()

w_size = 10
for key in keys:
    for i in range(EPOCHS-w_size):
        for j in range(4):
            filtered = filterout_nans(performance[key][:, j][i:i+w_size])
            performance[key][:, j][i] = np.mean(filtered)

# %%
def update_annot(line, ind):
    x,y = line.get_data()
    annot.xy = (0, 224)
    # print(line.get_label())
    text = f"{line.get_label()}"
    annot.set_text(text)
    annot.get_bbox_patch().set_alpha(0.4)

def hover(event):
    print('hover activated')
    vis = annot.get_visible()
    if event.inaxes == axes[0]:
        line = None
        for i in range(len(lines)):
            cont, ind = lines[i].contains(event)
            if cont:
                line = lines[i]
                break
        if cont:
            update_annot(line, ind)
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 15))
axes[0].set_title('Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('CrossEntropy')
axes[1].set_title('Accuracy')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
# axes[0].plot(range(len(train_loss_results)), train_loss_results, '-r', label='training')
lines = []

for key, i in zip(keys, range(n_keys)):
    tmp_loss_acc = performance[key]
    line, = axes[0].plot(range(EPOCHS-w_size), tmp_loss_acc[:, 2][:-w_size], c=cmap(norm(c[i])), label=key)
    lines.append(line)
    axes[1].plot(range(EPOCHS-w_size), tmp_loss_acc[:, 3][:-w_size], c=cmap(norm(c[i])), label=key)

for i in range(2):
    annot = axes[i].annotate("", xy=(0,0), xytext=(-20,20), textcoords="offset points",
                        bbox=dict(boxstyle="round", fc="w"),
                        arrowprops=dict(arrowstyle="->"))
    annot.set_visible(False)

axes[0].grid(True)
# axes[0].legend()
axes[1].grid(True)
fig.canvas.mpl_connect("motion_notify_event", hover)
# axes[1].legend()
# axes[1].plot(range(len(train_accuracy_results)), train_accuracy_results, '-r', label='training')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Best parameter found from the above plot using hover method on Pycharm... (256, 4, 0.1)

def create_model_2l(d_model, n_heads, dropout):

    D_MODEL = d_model

    input_key = Input(shape=[MAX_LEN], batch_size=BATCH_SIZE, dtype=tf.int16, name='input_key')
    input_query = Input(shape=[MAX_LEN], batch_size=BATCH_SIZE, dtype=tf.int16, name='input_query')

    # # Shift Right
    y = Lambda(lambda y: tf.pad(y, paddings=[[0, 0], [1, 0]]))(input_query)

    x = Embedding(input_dim=VOCAB_SIZE, output_dim=D_MODEL)(input_key)
    x += positional_encoding(MAX_LEN, D_MODEL)
    x = MultiHeadAttention(num_heads=n_heads, key_dim=D_MODEL, value_dim=D_MODEL, 
                           dropout=dropout, use_bias=True, kernel_regularizer='l2', 
                           bias_regularizer='l2')(query=x, value=x)
    
    y = Embedding(input_dim=VOCAB_SIZE, output_dim=D_MODEL)(y)
    y += positional_encoding(MAX_LEN+1, D_MODEL)
    y = MultiHeadAttention(num_heads=n_heads, key_dim=D_MODEL, value_dim=D_MODEL, 
                           dropout=dropout, use_bias=True, kernel_regularizer='l2', 
                           bias_regularizer='l2')(query=y, value=y)

    mask = np.tril(np.ones([1, MAX_LEN+1, MAX_LEN])) # batch_size x (length_of_query+1) x length_of_key

    output = MultiHeadAttention(num_heads=n_heads, key_dim=D_MODEL, value_dim=D_MODEL, 
                                dropout=dropout, use_bias=True, kernel_regularizer='l2', 
                                bias_regularizer='l2')(query=y, value=x)
    output = Lambda(lambda x: x[:, :-1])(output)
    output = LayerNormalization(axis=-1)(output)
    output = Dense(VOCAB_SIZE+1, use_bias=True, kernel_regularizer='l2', bias_regularizer='l2')(output)  # 0 for padding, and (1-VOCAB_SIZE) for words

    output = Softmax(axis=-1)(output)
    model = Model(inputs=[input_key, input_query], outputs=output)
    tb_callback = tf.keras.callbacks.TensorBoard('logs_full')
    tb_callback.set_model(model)
#     model.summary()
    return model

# %%
train_loss_results = []
train_accuracy_results = []

vl_loss_results = []
vl_accuracy_results = []

best_model_key = max(performance, key=performance.get)
d_model, n_heads, dropout = best_model_key.split(',')
d_model = int(d_model)
n_heads = int(n_heads)
dropout = float(dropout)

model3 = create_model_2l(128)
train(model=model3, epochs=10)

fig, axes = plt.subplots(1, 2, figsize=(15, 6))
axes[0].set_title('Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('CrossEntropy')
axes[0].plot(range(len(train_loss_results)), train_loss_results, '-r', label='training')
axes[0].plot(range(len(vl_loss_results)), vl_loss_results, '-b', label='validation')
axes[0].grid(True)
axes[0].legend()
axes[1].set_title('Accuracy')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
axes[1].plot(range(len(train_accuracy_results)), train_accuracy_results, '-r', label='training')
axes[1].plot(range(len(vl_accuracy_results)), vl_accuracy_results, '-b', label='validation')
axes[1].grid(True)
axes[1].legend()
plt.show()
# Out:
# Epoch 0 Loss: 237.938 Accuracy: 0.055 Val_Loss: 237.454 Val_Accuracy: 0.055
# Epoch 1 Loss: 231.840 Accuracy: 0.055 Val_Loss: 232.943 Val_Accuracy: 0.055
# Epoch 2 Loss: 230.886 Accuracy: 0.055 Val_Loss: 231.977 Val_Accuracy: 0.055
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-df63ffd0023f> in <module>
#       6
#       7 model3 = create_model_2l(128)
# ----> 8 train(model=model3, epochs=10)
#       9
#      10 fig, axes = plt.subplots(1, 2, figsize=(15, 6))
#
# <ipython-input-26-b3953a1f6092> in train(model, epochs, initial_epoch)
#      43             input_dict, target_dict = make_dict(tk_reviews, mask)
#      44             y_pred = model(input_dict)
# ---> 45             vl_loss = loss(target_dict, y_pred)
#      46             vl_acc = accuracy(target_dict, y_pred)
#      47
#
# <ipython-input-20-676822fb672d> in loss(y_true, y_pred)
#       5     loss = tf.reduce_sum(loss, axis=-1)
#       6     loss = tf.squeeze(loss)
# ----> 7     loss = loss * tf.cast(mask, dtype=tf.float32)
#       8     loss = tf.reduce_sum(loss, axis=-1)
#       9     loss = tf.reduce_mean(loss)
#
# ~/nightly/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/nightly/lib/python3.8/site-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#     957       x = ops.convert_to_tensor(x, name="x")
#     958       if x.dtype.base_dtype != base_type:
# --> 959         x = gen_math_ops.cast(x, base_type, name=name)
#     960     if x.dtype.is_complex and base_type.is_floating:
#     961       logging.warn("Casting complex to real discards imaginary part.")
#
# ~/nightly/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py in cast(x, DstT, Truncate, name)
#    1872   if tld.is_eager:
#    1873     try:
# -> 1874       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1875         _ctx, "Cast", name, x, "DstT", DstT, "Truncate", Truncate)
#    1876       return _result
#
# KeyboardInterrupt:
